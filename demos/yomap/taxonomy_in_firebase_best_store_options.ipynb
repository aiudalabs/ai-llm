# %%
import firebase_admin
from firebase_admin import credentials, firestore

# %%
# Initialize Firebase Admin SDK
cred = credentials.Certificate("goblob-95e2a-6add9b68fd5d.json")  # Replace with your JSON key
firebase_admin.initialize_app(cred)

# Get Firestore client
db = firestore.client()

# %% [markdown]
# # Option 3 - Flattened Collection

# %%
# Function to add a category (with description)
def add_category(category_id, category_name, description):
    db.collection("categories").document(category_id).set({
        "name": category_name,
        "description": description  # Added description
    })
    print(f"✅ Category '{category_name}' added!")

# Function to add a subcategory (with description)
def add_subcategory(subcategory_id, subcategory_name, category_id, description):
    db.collection("subcategories").document(subcategory_id).set({
        "name": subcategory_name,
        "category_id": category_id,
        "description": description  # Added description
    })
    print(f"✅ Subcategory '{subcategory_name}' added under category '{category_id}'!")

# Function to get all subcategories of a given category
def get_subcategories_by_category(category_id):
    subcategories = db.collection("subcategories").where("category_id", "==", category_id).get()
    result = [{**doc.to_dict(), "id": doc.id} for doc in subcategories]  # Include ID for reference
    return result

# ---- DEMO ----

# 1️⃣ Add Categories (with descriptions)
add_category("electronics", "Electronics", "Devices and gadgets like phones, laptops, and more.")
add_category("clothing", "Clothing", "Apparel and fashion for men, women, and kids.")

# 2️⃣ Add Subcategories (with descriptions)
add_subcategory("phones", "Phones", "electronics", "Smartphones and mobile devices.")
add_subcategory("laptops", "Laptops", "electronics", "Portable computers for work and gaming.")
add_subcategory("men", "Men", "clothing", "Men’s fashion including shirts, pants, and accessories.")
add_subcategory("women", "Women", "clothing", "Women’s fashion including dresses, shoes, and accessories.")

# 3️⃣ Query Subcategories by Category
electronics_subcategories = get_subcategories_by_category("electronics")
clothing_subcategories = get_subcategories_by_category("clothing")

# Print results
print("\n📌 Electronics Subcategories:")
for sub in electronics_subcategories:
    print(f"  - {sub['name']}: {sub['description']}")

print("\n📌 Clothing Subcategories:")
for sub in clothing_subcategories:
    print(f"  - {sub['name']}: {sub['description']}")
# Out:
# ✅ Category 'Electronics' added!
# ✅ Category 'Clothing' added!
# ✅ Subcategory 'Phones' added under category 'electronics'!
# ✅ Subcategory 'Laptops' added under category 'electronics'!
# ✅ Subcategory 'Men' added under category 'clothing'!
# ✅ Subcategory 'Women' added under category 'clothing'!
#
# 📌 Electronics Subcategories:
#   - Laptops: Portable computers for work and gaming.
#   - Phones: Smartphones and mobile devices.
#
# 📌 Clothing Subcategories:
#   - Men: Men’s fashion including shirts, pants, and accessories.
#   - Women: Women’s fashion including dresses, shoes, and accessories.

# %% [markdown]
# # Option 2 (Nested Subcollection Approach)

# %%
# Function to add a category (with description)
def add_category(category_id, category_name, description):
    db.collection("categories").document(category_id).set({
        "name": category_name,
        "description": description
    })
    print(f"✅ Category '{category_name}' added!")

# Function to add a subcategory inside a category (nested subcollection)
def add_subcategory(category_id, subcategory_id, subcategory_name, description):
    db.collection("categories").document(category_id).collection("subcategories").document(subcategory_id).set({
        "name": subcategory_name,
        "description": description
    })
    print(f"✅ Subcategory '{subcategory_name}' added under category '{category_id}'!")

# Function to get all subcategories for a given category
def get_subcategories_by_category(category_id):
    subcategories_ref = db.collection("categories").document(category_id).collection("subcategories").get()
    subcategories = [{**doc.to_dict(), "id": doc.id} for doc in subcategories_ref]  # Include ID for reference
    return subcategories

# ---- DEMO ----

# 1️⃣ Add Categories
add_category("electronics", "Electronics", "Devices and gadgets like phones, laptops, and more.")
add_category("clothing", "Clothing", "Apparel and fashion for men, women, and kids.")

# 2️⃣ Add Subcategories (inside their respective categories)
add_subcategory("electronics", "phones", "Phones", "Smartphones and mobile devices.")
add_subcategory("electronics", "laptops", "Laptops", "Portable computers for work and gaming.")
add_subcategory("clothing", "men", "Men", "Men’s fashion including shirts, pants, and accessories.")
add_subcategory("clothing", "women", "Women", "Women’s fashion including dresses, shoes, and accessories.")

# 3️⃣ Query Subcategories by Category
electronics_subcategories = get_subcategories_by_category("electronics")
clothing_subcategories = get_subcategories_by_category("clothing")

# Print results
print("\n📌 Electronics Subcategories:")
for sub in electronics_subcategories:
    print(f"  - {sub['name']}: {sub['description']}")

print("\n📌 Clothing Subcategories:")
for sub in clothing_subcategories:
    print(f"  - {sub['name']}: {sub['description']}")
# Out:
# ✅ Category 'Electronics' added!
# ✅ Category 'Clothing' added!
# ✅ Subcategory 'Phones' added under category 'electronics'!
# ✅ Subcategory 'Laptops' added under category 'electronics'!
# ✅ Subcategory 'Men' added under category 'clothing'!
# ✅ Subcategory 'Women' added under category 'clothing'!
#
# 📌 Electronics Subcategories:
#   - Laptops: Portable computers for work and gaming.
#   - Phones: Smartphones and mobile devices.
#
# 📌 Clothing Subcategories:
#   - Men: Men’s fashion including shirts, pants, and accessories.
#   - Women: Women’s fashion including dresses, shoes, and accessories.

# %% [markdown]
# # Now with profiles
#
# ## Flat Collections (Option 1)

# %%
# Function to add a category
def add_category(category_id, category_name, description):
    db.collection("categories").document(category_id).set({
        "name": category_name,
        "description": description
    })
    print(f"✅ Category '{category_name}' added!")

# Function to add a subcategory
def add_subcategory(subcategory_id, subcategory_name, category_id, description):
    db.collection("subcategories").document(subcategory_id).set({
        "name": subcategory_name,
        "category_id": category_id,
        "description": description
    })
    print(f"✅ Subcategory '{subcategory_name}' added under category '{category_id}'!")

# Function to add a service provider
def add_service_provider(sp_id, name, categories, subcategories, location, rating):
    db.collection("service_providers").document(sp_id).set({
        "name": name,
        "categories": categories,  # List of category IDs
        "subcategories": subcategories,  # List of subcategory IDs
        "location": location,
        "rating": rating
    })
    print(f"✅ Service Provider '{name}' added!")

# Function to find service providers by subcategory
def get_providers_by_subcategory(subcategory_id):
    providers_ref = db.collection("service_providers").where("subcategories", "array_contains", subcategory_id).get()
    return [{**doc.to_dict(), "id": doc.id} for doc in providers_ref]

# ---- DEMO ----

# 1️⃣ Add Categories
add_category("electronics", "Electronics", "Devices and gadgets like phones, laptops, and more.")
add_category("clothing", "Clothing", "Apparel and fashion for men, women, and kids.")

# 2️⃣ Add Subcategories
add_subcategory("phones", "Phones", "electronics", "Smartphones and mobile devices.")
add_subcategory("laptops", "Laptops", "electronics", "Portable computers for work and gaming.")
add_subcategory("men", "Men", "clothing", "Men’s fashion including shirts, pants, and accessories.")

# 3️⃣ Add Service Providers
add_service_provider("sp1", "John's Phone Repair", ["electronics"], ["phones"], "New York, USA", 4.7)
add_service_provider("sp2", "Elite Laptops Service", ["electronics"], ["laptops"], "San Francisco, USA", 4.9)
add_service_provider("sp3", "Men's Fashion Tailor", ["clothing"], ["men"], "Miami, USA", 4.8)

# 4️⃣ Query Providers by Subcategory
phone_repair_providers = get_providers_by_subcategory("phones")
print("\n📌 Phone Repair Providers:")
for sp in phone_repair_providers:
    print(f"  - {sp['name']} ({sp['location']}): {sp['rating']}⭐")
# Out:
# ✅ Category 'Electronics' added!
# ✅ Category 'Clothing' added!
# ✅ Subcategory 'Phones' added under category 'electronics'!
# ✅ Subcategory 'Laptops' added under category 'electronics'!
# ✅ Subcategory 'Men' added under category 'clothing'!
# ✅ Service Provider 'John's Phone Repair' added!
# ✅ Service Provider 'Elite Laptops Service' added!
# ✅ Service Provider 'Men's Fashion Tailor' added!
#
# 📌 Phone Repair Providers:
#   - John's Phone Repair (New York, USA): 4.7⭐

# %%
taxonomy = db.collection("tags-taxonomy").get()

# %%
for doc in taxonomy:
    print(doc.to_dict())
# Out:
# {'text': 'dog_walker', 'text_es': 'paseador_de_mascotas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'pets', 'parentId': '', 'isSystemCreated': True, 'slug': 'dog_walker'}
# {'text': 'elder_care', 'text_es': 'cuidado_de_ancianos', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'health', 'parentId': '', 'isSystemCreated': True, 'slug': 'elder_care'}
# {'text': 'air_conditioning_installations', 'text_es': 'instalaciones_de_aire_acondicionado', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'air_conditioning_installations'}
# {'text': 'gardening', 'text_es': 'jardineria', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'gardening'}
# {'text': 'diner', 'text_es': 'fonda', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'diner'}
# {'text': 'uber', 'text_es': 'uber', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'uber'}
# {'text': 'manicure', 'text_es': 'manicura', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'manicure'}
# {'text': 'errands', 'text_es': 'mandados', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'errands'}
# {'text': 'interior_design', 'text_es': 'decoracion', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'interior_design'}
# {'text': 'academic_support', 'text_es': 'apoyo_escolar', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'education', 'parentId': '', 'isSystemCreated': True, 'slug': 'academic_support'}
# {'text': 'breakfast', 'text_es': 'desayunos', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'breakfast'}
# {'text': 'electronics', 'text_es': 'electronica', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'electronics'}
# {'text': 'special_education', 'text_es': 'educacion_especial', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'education', 'parentId': '', 'isSystemCreated': True, 'slug': 'special_education'}
# {'text': 'televisions', 'text_es': 'televisores', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'televisions'}
# {'text': 'pet_adoption', 'text_es': 'adopcion_de_mascotas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'pets', 'parentId': '', 'isSystemCreated': True, 'slug': 'pet_adoption'}
# {'text': 'taxi', 'text_es': 'taxi', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'taxi'}
# {'text': 'moving_services', 'text_es': 'mudanzas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'moving_services'}
# {'text': 'body_treatments', 'text_es': 'tratamientos_corporales', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'body_treatments'}
# {'text': 'house_call_medicine', 'text_es': 'medicina_a_domicilio', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'health', 'parentId': '', 'isSystemCreated': True, 'slug': 'house_call_medicine'}
# {'text': 'cats', 'text_es': 'gatos', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'pets', 'parentId': '', 'isSystemCreated': True, 'slug': 'cats'}
# {'text': 'hair_removal', 'text_es': 'depilacion', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'hair_removal'}
# {'text': 'tutoring', 'text_es': 'tutorias', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'education', 'parentId': '', 'isSystemCreated': True, 'slug': 'tutoring'}
# {'text': 'music', 'text_es': 'musica', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'education', 'parentId': '', 'isSystemCreated': True, 'slug': 'music'}
# {'text': 'fruits', 'text_es': 'frutas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'fruits'}
# {'text': 'user', 'text_es': 'usuario', 'weight': 0, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'user'}
# {'text': 'computers', 'text_es': 'computadores', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'computers'}
# {'text': 'security_cameras', 'text_es': 'camaras_de_seguridad', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'security_cameras'}
# {'text': 'guided_tours', 'text_es': 'tours_guiados', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'guided_tours'}
# {'text': 'general_cleaning', 'text_es': 'limpieza_general', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'general_cleaning'}
# {'text': 'jewerly', 'text_es': 'joyeria', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'jewerly'}
# {'text': 'health', 'text_es': 'salud', 'weight': 6, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'health'}
# {'text': 'delivery', 'text_es': 'delivery', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'delivery'}
# {'text': 'appliance', 'text_es': 'electrodomesticos', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'appliance'}
# {'text': 'barber', 'text_es': 'barberia', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'barber'}
# {'text': 'vegetables', 'text_es': 'vegetales', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'vegetables'}
# {'text': 'yoga', 'text_es': 'yoga', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'yoga'}
# {'text': 'facial', 'text_es': 'limpieza_facial', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'facial'}
# {'text': 'pizza', 'text_es': 'pizza', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'pizza'}
# {'text': 'personal_trainer', 'text_es': 'entrenador_personal', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'health', 'parentId': '', 'isSystemCreated': True, 'slug': 'personal_trainer'}
# {'text': 'math', 'text_es': 'matematicas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'education', 'parentId': '', 'isSystemCreated': True, 'slug': 'math'}
# {'text': 'pools', 'text_es': 'piscinas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'pools'}
# {'text': 'window_cleaning', 'text_es': 'limpieza_de_ventanas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'window_cleaning'}
# {'text': 'paint', 'text_es': 'pintura', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'paint'}
# {'text': 'general_mechanics', 'text_es': 'mecanica_general', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'general_mechanics'}
# {'text': 'science', 'text_es': 'ciencias', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'education', 'parentId': '', 'isSystemCreated': True, 'slug': 'science'}
# {'text': 'refrigerators', 'text_es': 'neveras', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'refrigerators'}
# {'text': 'english', 'text_es': 'ingles', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'education', 'parentId': '', 'isSystemCreated': True, 'slug': 'english'}
# {'text': 'cars', 'text_es': 'carros', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'cars'}
# {'text': 'hot_dogs', 'text_es': 'perros_calientes', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'hot_dogs'}
# {'text': 'psychology', 'text_es': 'psicologia', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'health', 'parentId': '', 'isSystemCreated': True, 'slug': 'psychology'}
# {'text': 'repair', 'text_es': 'reparaciones', 'weight': 5, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'repair'}
# {'text': 'waterproofing', 'text_es': 'impermeabilizacion', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'waterproofing'}
# {'text': 'water_heater', 'text_es': 'calentador_de_agua', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'water_heater'}
# {'text': 'private_tutoring', 'text_es': 'clases_particulares', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'education', 'parentId': '', 'isSystemCreated': True, 'slug': 'private_tutoring'}
# {'text': 'massage', 'text_es': 'masajes', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'massage'}
# {'text': 'education', 'text_es': 'educacion', 'weight': 9, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'education'}
# {'text': 'lunch', 'text_es': 'almuerzos', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'lunch'}
# {'text': 'fast_food', 'text_es': 'comidas_rapidas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'fast_food'}
# {'text': 'babysitter', 'text_es': 'niñera', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'babysitter'}
# {'text': 'spa', 'text_es': 'spa', 'weight': 7, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'spa'}
# {'text': 'car_rental', 'text_es': 'renta_de_autos', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'car_rental'}
# {'text': 'watches', 'text_es': 'relojes', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'watches'}
# {'text': 'food', 'text_es': 'comida', 'weight': 4, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'food'}
# {'text': 'truck_driver', 'text_es': 'conductor_de_camion', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'truck_driver'}
# {'text': 'veterinary_services', 'text_es': 'servicios_veterinarios', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'pets', 'parentId': '', 'isSystemCreated': True, 'slug': 'veterinary_services'}
# {'text': 'carpool', 'text_es': 'viaje_compartido', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'carpool'}
# {'text': 'hairstyling', 'text_es': 'peluqueria', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'hairstyling'}
# {'text': 'private_driver', 'text_es': 'conductor_particular', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'private_driver'}
# {'text': 'nursing', 'text_es': 'enfermeria', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'health', 'parentId': '', 'isSystemCreated': True, 'slug': 'nursing'}
# {'text': 'school_bus', 'text_es': 'escolar', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'school_bus'}
# {'text': 'handyman', 'text_es': 'handyman', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'handyman'}
# {'text': 'alternative_medicine', 'text_es': 'medicina_alternativa', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'health', 'parentId': '', 'isSystemCreated': True, 'slug': 'alternative_medicine'}
# {'text': 'transport', 'text_es': 'transporte', 'weight': 1, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'transport'}
# {'text': 'chef', 'text_es': 'chef', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'chef'}
# {'text': 'tourism', 'text_es': 'turismo', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'tourism'}
# {'text': 'freight', 'text_es': 'mercancias', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'freight'}
# {'text': 'misc', 'text_es': 'otros', 'weight': 3, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'misc'}
# {'text': 'indriver', 'text_es': 'indriver', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'transport', 'parentId': '', 'isSystemCreated': True, 'slug': 'indriver'}
# {'text': 'electrician', 'text_es': 'electricista', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'electrician'}
# {'text': 'bicycles', 'text_es': 'bicicletas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'bicycles'}
# {'text': 'psychoeducational_support', 'text_es': 'psicopedagogia', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'education', 'parentId': '', 'isSystemCreated': True, 'slug': 'psychoeducational_support'}
# {'text': 'dentistry', 'text_es': 'odontologia', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'health', 'parentId': '', 'isSystemCreated': True, 'slug': 'dentistry'}
# {'text': 'dogs', 'text_es': 'perros', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'pets', 'parentId': '', 'isSystemCreated': True, 'slug': 'dogs'}
# {'text': 'makeup', 'text_es': 'maquillaje', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'makeup'}
# {'text': 'street_food', 'text_es': 'puesto_callejero', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'street_food'}
# {'text': 'pest_control', 'text_es': 'control_de_plagas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'pest_control'}
# {'text': 'sales', 'text_es': 'ventas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'misc', 'parentId': '', 'isSystemCreated': True, 'slug': 'sales'}
# {'text': 'furniture', 'text_es': 'muebles', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'furniture'}
# {'text': 'plumbing', 'text_es': 'plomeria', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'plumbing'}
# {'text': 'pet_grooming', 'text_es': 'peluqueria_de_mascotas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'pets', 'parentId': '', 'isSystemCreated': True, 'slug': 'pet_grooming'}
# {'text': 'washing_machines', 'text_es': 'lavadoras', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'washing_machines'}
# {'text': 'motorcycles', 'text_es': 'motos', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'motorcycles'}
# {'text': 'pet_care', 'text_es': 'cuidado_de_mascotas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'pets', 'parentId': '', 'isSystemCreated': True, 'slug': 'pet_care'}
# {'text': 'pedicure', 'text_es': 'pedicura', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'spa', 'parentId': '', 'isSystemCreated': True, 'slug': 'pedicure'}
# {'text': 'pets', 'text_es': 'mascotas', 'weight': 8, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'pets'}
# {'text': 'cell_phones', 'text_es': 'celulares', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'cell_phones'}
# {'text': 'carpentry', 'text_es': 'carpinteria', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'carpentry'}
# {'text': 'home', 'text_es': 'hogar', 'weight': 2, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': '', 'parentId': '', 'isSystemCreated': True, 'slug': 'home'}
# {'text': 'kitchen_installation', 'text_es': 'montaje_de_cocinas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'kitchen_installation'}
# {'text': 'gas_installations', 'text_es': 'instalaciones_de_gas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'gas_installations'}
# {'text': 'construction_worker', 'text_es': 'albañil', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'home', 'parentId': '', 'isSystemCreated': True, 'slug': 'construction_worker'}
# {'text': 'pet_training', 'text_es': 'adiestramiento', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'pets', 'parentId': '', 'isSystemCreated': True, 'slug': 'pet_training'}
# {'text': 'physical_therapy', 'text_es': 'fisioterapia', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'health', 'parentId': '', 'isSystemCreated': True, 'slug': 'physical_therapy'}
# {'text': 'food_truck', 'text_es': 'food_truck', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'food_truck'}
# {'text': 'pet_supplies', 'text_es': 'productos_para_mascotas', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'pets', 'parentId': '', 'isSystemCreated': True, 'slug': 'pet_supplies'}
# {'text': 'air_conditioning', 'text_es': 'aire_acondicionado', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'repair', 'parentId': '', 'isSystemCreated': True, 'slug': 'air_conditioning'}
# {'text': 'home_coocked', 'text_es': 'comida_casera', 'weight': 10, 'isService': True, 'dateCreated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'dateUpdated': DatetimeWithNanoseconds(2025, 3, 10, 4, 32, 21, 543000, tzinfo=datetime.timezone.utc), 'usedBy': 0, 'parentSlug': 'food', 'parentId': '', 'isSystemCreated': True, 'slug': 'home_coocked'}

# %%
import asyncio
from crawl4ai import *

import nest_asyncio

nest_asyncio.apply()

async def main():
    async with AsyncWebCrawler() as crawler:
        result = await crawler.arun(
            url="https://www.airtasker.com/au/services/",
        )
        print(result.markdown)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# [INIT].... → Crawl4AI 0.4.246
# [FETCH]... ↓ https://www.airtasker.com/au/services/... | Status: True | Time: 0.07s
# [COMPLETE] ● https://www.airtasker.com/au/services/... | Status: True | Total: 0.08s
# [](https://www.airtasker.com/au/services/</au/>)[+](https://www.airtasker.com/au/services/</post-task/?origin=header_post_task-seo>)
# [](https://www.airtasker.com/au/services/</au/>)
# [Post a task](https://www.airtasker.com/au/services/</post-task/?origin=header_post_task-seo>)
# [Categories](https://www.airtasker.com/au/services/</au/services/>)
# What are you looking for?
# Pick a type of task.
# As a tasker
# I'm looking for work in ...
# As a poster
# I’m looking to hire someone for ...
#   * [Accountants](https://www.airtasker.com/au/services/</au/services/accounting/>)
#   * [Admin](https://www.airtasker.com/au/services/</au/services/admin/>)
#   * [Alterations](https://www.airtasker.com/au/services/</au/services/alteration/>)
#   * [Appliances](https://www.airtasker.com/au/services/</au/services/appliance-servicing/>)
#   * [Assembly](https://www.airtasker.com/au/services/</au/services/assembly/>)
#   * [Auto Electricians](https://www.airtasker.com/au/services/</au/services/auto-electrician/>)
#   * [Bakers](https://www.airtasker.com/au/services/</au/services/baking/>)
#   * [Barbers](https://www.airtasker.com/au/services/</au/services/barber/>)
#   * [Beauticians](https://www.airtasker.com/au/services/</au/services/beautician/>)
#   * [Bicycle Service](https://www.airtasker.com/au/services/</au/services/bicycle/>)
#   * [Bricklaying](https://www.airtasker.com/au/services/</au/services/bricklaying/>)
#   * [Building & Construction](https://www.airtasker.com/au/services/</au/services/building-construction/>)
#   * [Business](https://www.airtasker.com/au/services/</au/services/business/>)
#   * [Car Body Work](https://www.airtasker.com/au/services/</au/services/car-bodywork/>)
#   * [Car Detailing](https://www.airtasker.com/au/services/</au/services/car-detailing/>)
#   * [Car Repair](https://www.airtasker.com/au/services/</au/services/car-repair/>)
#   * [Car Service](https://www.airtasker.com/au/services/</au/services/car-servicing/>)
#   * [Carpentry](https://www.airtasker.com/au/services/</au/services/carpentry/>)
#   * [Cat Care](https://www.airtasker.com/au/services/</au/services/cat-care/>)
#   * [Catering](https://www.airtasker.com/au/services/</au/services/catering/>)
#   * [Chef](https://www.airtasker.com/au/services/</au/services/chef/>)
#   * [Cladding](https://www.airtasker.com/au/services/</au/services/cladding/>)
#   * [Cleaning](https://www.airtasker.com/au/services/</au/services/cleaning/>)
#   * [Computers & IT](https://www.airtasker.com/au/services/</au/services/computers/>)
#   * [Concreting](https://www.airtasker.com/au/services/</au/services/concreting/>)
#   * [Decking](https://www.airtasker.com/au/services/</au/services/decking/>)
#   * [Delivery](https://www.airtasker.com/au/services/</au/services/delivery/>)
#   * [Design](https://www.airtasker.com/au/services/</au/services/design/>)
#   * [Dog Care](https://www.airtasker.com/au/services/</au/services/dog-care/>)
#   * [Draftsman](https://www.airtasker.com/au/services/</au/services/draftsman/>)
#   * [Driving](https://www.airtasker.com/au/services/</au/services/driving/>)
#   * [Electricians](https://www.airtasker.com/au/services/</au/services/electrician/>)
#   * [Entertainment](https://www.airtasker.com/au/services/</au/services/entertainment/>)
#   * [Events](https://www.airtasker.com/au/services/</au/services/events/>)
#   * [Fencing](https://www.airtasker.com/au/services/</au/services/fencing/>)
#   * [Flooring](https://www.airtasker.com/au/services/</au/services/flooring/>)
#   * [Florist](https://www.airtasker.com/au/services/</au/services/florist/>)
#   * [Furniture Assembly](https://www.airtasker.com/au/services/</au/services/furniture-assembly/>)
#   * [Gardening](https://www.airtasker.com/au/services/</au/services/gardening/>)
#   * [Gate Installation](https://www.airtasker.com/au/services/</au/services/gate-installation/>)
#   * [Hairdressers](https://www.airtasker.com/au/services/</au/services/hairdresser/>)
#   * [Handyman](https://www.airtasker.com/au/services/</au/services/handyman/>)
#   * [Heating & Cooling](https://www.airtasker.com/au/services/</au/services/heating-cooling/>)
#   * [Home Automation and Security](https://www.airtasker.com/au/services/</au/services/home-automation-security/>)
#   * [Home Theatre](https://www.airtasker.com/au/services/</au/services/home-theatre/>)
#   * [Interior Designer](https://www.airtasker.com/au/services/</au/services/interior-design/>)
#   * [Landscaping](https://www.airtasker.com/au/services/</au/services/landscaping/>)
#   * [Laundry](https://www.airtasker.com/au/services/</au/services/laundry-services/>)
#   * [Lawn Care](https://www.airtasker.com/au/services/</au/services/lawn-care/>)
#   * [Lessons](https://www.airtasker.com/au/services/</au/services/lessons/>)
#   * [Locksmith](https://www.airtasker.com/au/services/</au/services/locksmith/>)
#   * [Makeup Artist](https://www.airtasker.com/au/services/</au/services/makeup-artist/>)
#   * [Marketing](https://www.airtasker.com/au/services/</au/services/marketing/>)
#   * [Mobile Mechanic](https://www.airtasker.com/au/services/</au/services/mobile-mechanic/>)
#   * [Painting](https://www.airtasker.com/au/services/</au/services/painting/>)
#   * [Paving](https://www.airtasker.com/au/services/</au/services/paving/>)
#   * [Pest Control](https://www.airtasker.com/au/services/</au/services/pest-control/>)
#   * [Pet Care](https://www.airtasker.com/au/services/</au/services/pet-care/>)
#   * [Photographers](https://www.airtasker.com/au/services/</au/services/photographer/>)
#   * [Plasterer](https://www.airtasker.com/au/services/</au/services/plasterer/>)
#   * [Plumbing](https://www.airtasker.com/au/services/</au/services/plumbing/>)
#   * [Pool Maintenance](https://www.airtasker.com/au/services/</au/services/pool-maintenance/>)
#   * [Removals](https://www.airtasker.com/au/services/</au/services/removals/>)
#   * [Roofing](https://www.airtasker.com/au/services/</au/services/roofing/>)
#   * [Sharpening](https://www.airtasker.com/au/services/</au/services/sharpening/>)
#   * [Staffing](https://www.airtasker.com/au/services/</au/services/staffing/>)
#   * [Tailors](https://www.airtasker.com/au/services/</au/services/tailoring/>)
#   * [Tattoo Artists](https://www.airtasker.com/au/services/</au/services/tattoo-artist/>)
#   * [Tiling](https://www.airtasker.com/au/services/</au/services/tiling/>)
#   * [Tradesman](https://www.airtasker.com/au/services/</au/services/tradesman/>)
#   * [Tutoring](https://www.airtasker.com/au/services/</au/services/tutoring/>)
#   * [Wall Hanging & Mounting](https://www.airtasker.com/au/services/</au/services/wall-hanging-mounting/>)
#   * [Wallpapering](https://www.airtasker.com/au/services/</au/services/wallpapering/>)
#   * [Waterproofing](https://www.airtasker.com/au/services/</au/services/waterproofing/>)
#   * [Web](https://www.airtasker.com/au/services/</au/services/web/>)
#   * [Wheel & Tyre Service](https://www.airtasker.com/au/services/</au/services/wheel-tyre-service/>)
#   * [Writing](https://www.airtasker.com/au/services/</au/services/writing/>)
#   * [View all](https://www.airtasker.com/au/services/</au/services/>)
#
#
# [Browse tasks](https://www.airtasker.com/au/services/</tasks/>)[How it works](https://www.airtasker.com/au/services/</au/how-it-works/>)
# [Sign up](https://www.airtasker.com/au/services/<#>)[Log in](https://www.airtasker.com/au/services/<#>)[Become a Tasker](https://www.airtasker.com/au/services/</au/earn-money/>)
#   * Accounting
#   * Admin
#   * Alterations
#   * Appliances
#   * Architects
#   * Assembly
#   * Audio Visual
#   * Auto Electrician
#   * Bakers
#   * Balloon Delivery
#   * Barbers
#   * Bathroom Renovation
#   * Beauticians
#   * Bicycle Service
#   * Bricklayer
#   * Building & Construction
#   * Business
#   * Cake Delivery
#   * Car Body Work
#   * Car Detailing
#   * Car Inspection
#   * Car Repair
#   * Car Service
#   * Car Wash
#   * Carpentry
#   * Carpet Cleaning
#   * Cat Care
#   * Catering
#   * Chef
#   * Childcare & Safety
#   * Cladding
#   * Cleaning
#   * Clearance Services
#   * Coaching
#   * Coffee Delivery
#   * Commercial Cleaning
#   * Computers & IT
#   * Concreting
#   * Cooking
#   * Counselling & Therapy
#   * Courier Services
#   * Dance Lessons
#   * Decking
#   * Delivery
#   * Design
#   * Dessert Delivery
#   * Dog Care
#   * Draftsman
#   * Driving
#   * Electricians
#   * Electronic Repair
#   * Engraving
#   * Entertainment
#   * Events
#   * Fencing
#   * Fitness
#   * Flooring
#   * Florist
#   * Flower Delivery
#   * Food Delivery
#   * Fresh Food Delivery
#   * Furniture Assembly
#   * Furniture Repair
#   * Gardening
#   * Gate Installation
#   * Gift Delivery
#   * Glaziers
#   * Grocery Delivery
#   * Hair Removal
#   * Hairdressers
#   * Handyman
#   * Health & Wellness
#   * Heating & Cooling
#   * Home & Lifestyle
#   * Home Automation and Security
#   * Home Theatre
#   * House Cleaning
#   * Interior Designer
#   * Kitchen Renovation
#   * Landscaping
#   * Laundry
#   * Lawn Care
#   * Legal Services
#   * Lessons
#   * Local Mobile Mechanic
#   * Locksmith
#   * Makeup Artist
#   * Marketing
#   * Martial Arts
#   * Mechanic
#   * Models
#   * Motorcycle Mechanic
#   * Music Lessons
#   * Painting
#   * Paving
#   * Pest Control
#   * Pet Care
#   * Photographers
#   * Plasterer
#   * Plumbing
#   * Pool Maintenance
#   * Real Estate
#   * Removals
#   * Roofing
#   * Rubbish Removal
#   * Seamstress
#   * Sharpening
#   * Staffing
#   * Surveyors
#   * Swimming Lessons
#   * Tailors
#   * Takeaway & Delivery
#   * Tattoo Artists
#   * Tiling
#   * Tradesman
#   * Translation
#   * Tree Surgeons
#   * Tutoring
#   * Vehicle Transport
#   * Wall Hanging and Mounting
#   * Wallpapering
#   * Waste Collection & Disposal
#   * Waterproofing
#   * Web
#   * Wedding
#   * Wheel & Tyre Service
#   * Window Cleaning
#   * Windows & Doors
#   * Writing
#
#
# # **What's on your list?**
# To-do list never getting shorter? Take the burden off and find the help you need on Airtasker.And if you're wondering what kinds of things people actually get done on here - look no further!Here are some of our most popular task categories...
# ## [Accounting](https://www.airtasker.com/au/services/</au/services/accounting/>)
# Managing finances is a piece of cake… said no one ever! Except, of course, for those who work with a trusted accountant. With Airtasker, you can find expert advice from an independent accountant for your personal and new business needs in minutes. Here’s why booking a Tasker is the way to go:
# ![Tasker performing a Accounting job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_AU/1673504431941-busy-accountant-working.png)
# [Budgeting Help](https://www.airtasker.com/au/services/</au/services/budgeting/>)[Financial Advisor](https://www.airtasker.com/au/services/</au/services/financial-advisor/>)[Financial Modelling](https://www.airtasker.com/au/services/</au/services/financial-modelling/>)[Financial Planning](https://www.airtasker.com/au/services/</au/services/financial-planning/>)[Financial Reporting](https://www.airtasker.com/au/services/</au/services/financial-reporting/>)[MYOB Training](https://www.airtasker.com/au/services/</au/services/myob-training/>)[Mortgage Advisor ](https://www.airtasker.com/au/services/</au/services/mortgage-advisor/>)[Pension Advisor](https://www.airtasker.com/au/services/</au/services/pension-advisor/>)[Tax Advisor](https://www.airtasker.com/au/services/</au/services/tax-advisor/>)[XERO Training](https://www.airtasker.com/au/services/</au/services/xero-training/>)
# ## [Admin](https://www.airtasker.com/au/services/</au/services/admin/>)
# Find a reliable admin assistant at short notice, for as long as you need. Airtasker connects you with rated and reviewed admin Tasker in minutes. So if you suddenly need extra hands at the office, or if your full-time assistant called in sick, no need to fret! Simply put up a task and wait for local admin assistants to get in touch.
# ![Tasker performing a Admin job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_AU/1673527743996-woman-working-on-computer.jpg)
# [Data Entry](https://www.airtasker.com/au/services/</au/services/data-entry/>)[Document Filing](https://www.airtasker.com/au/services/</au/services/document-filing/>)[HR Services](https://www.airtasker.com/au/services/</au/services/human-resource/>)[Office Work](https://www.airtasker.com/au/services/</au/services/office-admin-work/>)[Personal Assistant](https://www.airtasker.com/au/services/</au/services/personal-assistant/>)[Research Assistant](https://www.airtasker.com/au/services/</au/services/research-assistant/>)[Typist](https://www.airtasker.com/au/services/</au/services/typist/>)[Virtual Assistant](https://www.airtasker.com/au/services/</au/services/virtual-assistant/>)[eBay Selling Assistance](https://www.airtasker.com/au/services/</au/services/ebay-selling-assistance/>)
# ## [Alterations](https://www.airtasker.com/au/services/</au/services/alteration/>)
# Perhaps your clothing doesn’t quite fit right, or you need a few clothing repairs? Book alterations near you and get your favourite outfits ready to wear again, with the perfect fit. Your seamstress has the equipment and experience to work with your clothing and textiles so they can fit your exact measurements and body type. Or they can match up missing buttons, repair broken zips, and even patch small holes. Your clothes will be ready to go in no time.
# ![Tasker performing a Alterations job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_AU/1673575939172-woman-making-alterations.jpg)
# [Wedding Dress Alterations](https://www.airtasker.com/au/services/</au/services/wedding-dress-alteration/>)[Zipper Repair](https://www.airtasker.com/au/services/</au/services/zipper-repair/>)
# ## [Appliances](https://www.airtasker.com/au/services/</au/services/appliance-servicing/>)
# Looking for an appliance technician? Whether you need a new appliance installed or an appliance service or repair, a professional technician can help. They’ll install or repair your whitegoods, oven, or electrical appliance with all the right tools and experience to get your goods up and running, and ready for use.
# ![Tasker performing a Appliances job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_AU/1673575981043-man-installing-appliances.jpg)
# [Appliance Installation](https://www.airtasker.com/au/services/</au/services/appliance-installation/>)[Appliance Repair](https://www.airtasker.com/au/services/</au/services/appliance-repair/>)[Bosch Appliance Repair](https://www.airtasker.com/au/services/</au/services/bosch-appliance-repair/>)[Coffee Machine Repairs](https://www.airtasker.com/au/services/</au/services/coffee-machine-repair/>)[Cooker Hood Installation & Repair](https://www.airtasker.com/au/services/</au/services/cooker-hood-installation-repair/>)[Cooktop Installation](https://www.airtasker.com/au/services/</au/services/cooktop-installation/>)[Dishdrawer Installation](https://www.airtasker.com/au/services/</au/services/dishdrawer-installation/>)[Dishwasher Not Draining](https://www.airtasker.com/au/services/</au/services/dishwasher-not-draining/>)[Dishwasher Repair](https://www.airtasker.com/au/services/</au/services/dishwasher-repair/>)[Dryer Installation](https://www.airtasker.com/au/services/</au/services/dryer-installation/>)[Freezer Installation](https://www.airtasker.com/au/services/</au/services/freezer-installation/>)[Fridge Repair & Installation](https://www.airtasker.com/au/services/</au/services/fridge-repair-installation/>)[Gas Fitters](https://www.airtasker.com/au/services/</au/services/gas-fitting/>)[Gas Oven Repair and Installation](https://www.airtasker.com/au/services/</au/services/gas-oven-installation-repair/>)[Gas Stove Installation & Repair](https://www.airtasker.com/au/services/</au/services/gas-stove-installation-repair/>)[Ice Machine Repair & Installation](https://www.airtasker.com/au/services/</au/services/ice-machine-installation-repair/>)[Microwave Repair](https://www.airtasker.com/au/services/</au/services/microwave-repair/>)[Oven Fan Repair](https://www.airtasker.com/au/services/</au/services/oven-fan-repair/>)[Oven Repair](https://www.airtasker.com/au/services/</au/services/oven-repair/>)[Rangehood Installation](https://www.airtasker.com/au/services/</au/services/rangehood-installation/>)[Rangehood Repairs](https://www.airtasker.com/au/services/</au/services/rangehood-repair/>)[Samsung Fridge Repair](https://www.airtasker.com/au/services/</au/services/samsung-fridge-repair/>)[Stove Connection](https://www.airtasker.com/au/services/</au/services/stove-connection/>)[Stove Installation](https://www.airtasker.com/au/services/</au/services/stove-installation/>)[Vacuum Cleaner Repair](https://www.airtasker.com/au/services/</au/services/vacuum-cleaner-repair/>)[Washing Machine Levelling](https://www.airtasker.com/au/services/</au/services/washing-machine-levelling/>)[Washing Machine Repairs & Installation](https://www.airtasker.com/au/services/</au/services/washing-machine-installation-repair/>)
# ## [Architects](https://www.airtasker.com/au/services/</au/services/architect/>)
# Building your dream home? Although your personal choices are important, you can’t just plan its design on your own. The same applies for commercial properties.
# ![Tasker performing a Architects job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_AU/1673576095210-architect-working-on-floor-plan.jpg)
# [Architectural Rendering & Visualisation](https://www.airtasker.com/au/services/</au/services/architectural-rendering/>)[Building Designers](https://www.airtasker.com/au/services/</au/services/building-design/>)[Floor Planning](https://www.airtasker.com/au/services/</au/services/floor-planning/>)[Garage Conversion](https://www.airtasker.com/au/services/</au/services/garage-conversion/>)[House Extensions](https://www.airtasker.com/au/services/</au/services/house-extension/>)[House Renovation](https://www.airtasker.com/au/services/</au/services/house-renovation/>)[Interior Architects](https://www.airtasker.com/au/services/</au/services/interior-architect/>)[Loft Conversion](https://www.airtasker.com/au/services/</au/services/loft-conversion/>)
# ## [Assembly](https://www.airtasker.com/au/services/</au/services/assembly/>)
# Love shopping for new furniture, but hate putting it together? Hire a furniture assembly expert and they’ll take care of unboxing and building your new furniture for you. And because they’re pros at assembling flatpack furniture, you can enjoy peace of mind, knowing that your flatpack furniture is put together correctly and securely, using the best tools. With the right help, you can save time, avoid testing your patience, and start using your new furniture sooner.
# ![Tasker performing a Assembly job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_AU/1673576241853-man-working-on-table-assembly.jpg)
# [BBQ Assembly](https://www.airtasker.com/au/services/</au/services/bbq-assembly/>)[Basketball Hoop System Assembly](https://www.airtasker.com/au/services/</au/services/basketball-hoop-system-assembly/>)[Bunnings Assembly](https://www.airtasker.com/au/services/</au/services/bunnings-assembly/>)[Cube Storage Assembly](https://www.airtasker.com/au/services/</au/services/cube-storage-assembly/>)[Disassembly](https://www.airtasker.com/au/services/</au/services/assembly-disassembly/>)[Exercise Bike Assembly](https://www.airtasker.com/au/services/</au/services/exercise-bike-assembly/>)[Fantastic Furniture Assembly](https://www.airtasker.com/au/services/</au/services/fantastic-furniture-assembly/>)[Harvey Norman Furniture Assembly](https://www.airtasker.com/au/services/</au/services/harvey-norman-assembly/>)[Home Gym Assembly](https://www.airtasker.com/au/services/</au/services/home-gym-assembly/>)[Inversion Table Assembly](https://www.airtasker.com/au/services/</au/services/inversion-table-assembly/>)[Kids Bike Assembly](https://www.airtasker.com/au/services/</au/services/kids-bike-assembly/>)[Nordictrack Assembly](https://www.airtasker.com/au/services/</au/services/nordictrack-assembly/>)[PC Assembly](https://www.airtasker.com/au/services/</au/services/pc-assembly/>)[Playground Assembly](https://www.airtasker.com/au/services/</au/services/playground-assembly/>)[Pool Table Assembly](https://www.airtasker.com/au/services/</au/services/pool-table-assembly/>)[Spring Free Trampoline Assembly](https://www.airtasker.com/au/services/</au/services/spring-free-trampoline-assembly/>)[Swing Set Assembly](https://www.airtasker.com/au/services/</au/services/swing-set-assembly/>)[Table Tennis Table Assembly](https://www.airtasker.com/au/services/</au/services/table-tennis-table-assembly/>)[Toy Assembly](https://www.airtasker.com/au/services/</au/services/toy-assembly/>)[Trampoline Assembly](https://www.airtasker.com/au/services/</au/services/trampoline-assembly/>)[Treadmill Assembly](https://www.airtasker.com/au/services/</au/services/treadmill-assembly/>)[Vuly Trampoline Assembly](https://www.airtasker.com/au/services/</au/services/vuly-trampoline-assembly/>)
# ## [Audio Visual](https://www.airtasker.com/au/services/</au/services/audio-visual/>)
# Whether you need audiovisual services for an event or an av professional to edit and produce your audio and video recordings, Airtasker is your go-to place. Book an av for events to help create the perfect atmosphere for your conference, concert, or party. Focus on your guests while your av professional worries about managing the technical aspects.
# [Music Production](https://www.airtasker.com/au/services/</au/services/music-production/>)[Video Editing](https://www.airtasker.com/au/services/</au/services/video-editing/>)[Video Production](https://www.airtasker.com/au/services/</au/services/video-production/>)[Videographers](https://www.airtasker.com/au/services/</au/services/videography/>)
# ## [Auto Electrician](https://www.airtasker.com/au/services/</au/services/auto-electrician/>)
# New cars have complex inbuilt electrical systems, so when something goes wrong, don’t try and fix the problem yourself. Instead, hire a local auto electrician to help fix problems in your car, trailer, and even your boat. Using specialised diagnostic equipment, the technician will find the problem and do the necessary auto electrical repairs.
# [Alternator Replacement](https://www.airtasker.com/au/services/</au/services/alternator-replacement/>)[Car Alarm System Repair](https://www.airtasker.com/au/services/</au/services/car-alarm-system-repair/>)[Car Battery Replacement](https://www.airtasker.com/au/services/</au/services/auto-electrician-car-battery-replacement/>)[Car CD Player Installation](https://www.airtasker.com/au/services/</au/services/car-cd-player-installation/>)[Car Electrical Repair](https://www.airtasker.com/au/services/</au/services/car-electrical-repair/>)[Car Keyless Entry System Installation](https://www.airtasker.com/au/services/</au/services/car-keyless-entry-system-installation/>)[Car Speaker Installation](https://www.airtasker.com/au/services/</au/services/car-speaker-installation/>)[Car Stereo Installation](https://www.airtasker.com/au/services/</au/services/car-stereo-installation/>)[Central Locking Installation](https://www.airtasker.com/au/services/</au/services/central-locking-installation/>)[Dash Cam Installation](https://www.airtasker.com/au/services/</au/services/dash-cam-installation/>)[Electric Car Service](https://www.airtasker.com/au/services/</au/services/electric-car-service/>)[Glow Plug Replacement](https://www.airtasker.com/au/services/</au/services/glow-plug-replacement/>)[Headlight Bulb Replacement](https://www.airtasker.com/au/services/</au/services/headlight-bulb-replacement/>)[Ignition Systems Repair](https://www.airtasker.com/au/services/</au/services/ignition-systems-repair/>)[LED Lights Installation](https://www.airtasker.com/au/services/</au/services/led-lights-installation/>)[Parking Sensor Replacement](https://www.airtasker.com/au/services/</au/services/parking-sensor-replacement/>)[Reversing Camera Installation](https://www.airtasker.com/au/services/</au/services/reversing-camera-installation/>)[Starter Motor Repair](https://www.airtasker.com/au/services/</au/services/starter-motor-repair/>)[UHF Radio Installations](https://www.airtasker.com/au/services/</au/services/uhf-radio-installation/>)
# ## [Bakers](https://www.airtasker.com/au/services/</au/services/baking/>)
# There’s no need to drive to the nearest bakery near you or go through dozens of artisan bakery or wheat-free bakery accounts online. Airtasker can connect you to local bakeries and pastry chefs for all the needs of your sweet tooth. If you’re planning the perfect cake or cupcake tower for a wedding, birthday, or any other special occasion, a Tasker can help.
# [Artisan Baker](https://www.airtasker.com/au/services/</au/services/artisan-baker/>)[Cake Decorators](https://www.airtasker.com/au/services/</au/services/cake-decorator/>)[Cake Toppers](https://www.airtasker.com/au/services/</au/services/cake-topper-maker/>)[Celebration Cakes](https://www.airtasker.com/au/services/</au/services/celebration-cake-baker/>)[Custom Birthday Cakes](https://www.airtasker.com/au/services/</au/services/custom-birthday-cake-baker/>)[Custom Cakes](https://www.airtasker.com/au/services/</au/services/custom-cake-baker/>)[French Baker](https://www.airtasker.com/au/services/</au/services/french-baker/>)[Gluten Free Baker](https://www.airtasker.com/au/services/</au/services/gluten-free-baker/>)[Greek Baker](https://www.airtasker.com/au/services/</au/services/greek-baker/>)[Japanese Baker](https://www.airtasker.com/au/services/</au/services/japanese-baker/>)[Keto Baker](https://www.airtasker.com/au/services/</au/services/keto-baker/>)[Personalised Cupcakes](https://www.airtasker.com/au/services/</au/services/personalised-cupcake-baker/>)[Vegan Baker](https://www.airtasker.com/au/services/</au/services/vegan-baker/>)[Wedding Cakes](https://www.airtasker.com/au/services/</au/services/wedding-cake-baker/>)[Wholesale Baker](https://www.airtasker.com/au/services/</au/services/wholesale-baker/>)
# ## [Balloon Delivery](https://www.airtasker.com/au/services/</au/services/balloon-delivery/>)
# Balloons can brighten someone’s day or jazz up your next event. So if you’re planning a special gesture or decorating a venue, you can find reliable & affordable balloon delivery services on Airtasker.
# [Birthday Balloon Delivery](https://www.airtasker.com/au/services/</au/services/birthday-balloon-delivery/>)[Flower & Balloon Delivery](https://www.airtasker.com/au/services/</au/services/flower-balloon-delivery/>)[Inflated Helium Balloon Delivery](https://www.airtasker.com/au/services/</au/services/inflated-helium-balloon-delivery/>)[Personalised Balloon Delivery](https://www.airtasker.com/au/services/</au/services/personalised-balloon-delivery/>)
# ## [Barbers](https://www.airtasker.com/au/services/</au/services/barber/>)
# With Airtasker, finding a hair barber near you who can cut your hair or groom your beard the way you want to is only a few taps away! Before booking a Tasker, you may check their profiles, ratings, and reviews to see what other people say about their services. You can make sure that you'll get one of the rated barbers around you.
# [Beard Grooming](https://www.airtasker.com/au/services/</au/services/beard-grooming/>)[Mobile Barbers](https://www.airtasker.com/au/services/</au/services/mobile-barber/>)
# ## [Bathroom Renovation](https://www.airtasker.com/au/services/</au/services/bathroom-renovation/>)
# Searching for a bathroom renovator? Whether you want to update your bathroom, create more space, or add value before listing your home for sale, you’re in the right place. Find bathroom renovation services near you and finally give your bathroom the refresh it needs.
# ## [Beauticians](https://www.airtasker.com/au/services/</au/services/beautician/>)
# Looking for an experienced beautician near you for your next event or special occasion? When you hire a beauty therapist, you can enjoy professional help with everything from hair and makeup to spray tanning, manicures, pedicures, and more. They’ll come prepared with all of the latest products, tools, and equipment so you can just relax..Whether you’ve got a special event planned or you want to maintain your regular beauty regime, your therapist will help you look and feel your best.
# [Eyebrow Microblading](https://www.airtasker.com/au/services/</au/services/eyebrow-microblading/>)[Eyebrow Threading](https://www.airtasker.com/au/services/</au/services/eyebrow-threading/>)[Eyebrow Waxing](https://www.airtasker.com/au/services/</au/services/eyebrow-waxing/>)[Eyelash Extensions](https://www.airtasker.com/au/services/</au/services/eyelash-extension/>)[Eyelash Lift and Tint](https://www.airtasker.com/au/services/</au/services/eyelash-lift-tint/>)[Eyelash Perming](https://www.airtasker.com/au/services/</au/services/eyelash-perming/>)[Manicure](https://www.airtasker.com/au/services/</au/services/manicure/>)[Nail Technicians](https://www.airtasker.com/au/services/</au/services/nail-technician/>)[Pedicure](https://www.airtasker.com/au/services/</au/services/pedicure/>)[Spray Tanning](https://www.airtasker.com/au/services/</au/services/spray-tanning/>)
# ## [Bicycle Service](https://www.airtasker.com/au/services/</au/services/bicycle/>)
# Booking a bicycle service nearby with Airtasker is easier than setting up an appointment with a bicycle shop. It's also safer than trying to service your bike yourself! Whether you need to get a basic maintenance check or have your flat tyres repaired, we can lend a helping hand. No delays, no fuss, and no risky DIY jobs.
# [Bicycle Assembly](https://www.airtasker.com/au/services/</au/services/bicycle-assembly/>)[Bicycle Courier](https://www.airtasker.com/au/services/</au/services/bicycle-courier/>)[Bicycle Tyre Repair](https://www.airtasker.com/au/services/</au/services/bicycle-tyre-repair/>)[Bike Frame Painting Service](https://www.airtasker.com/au/services/</au/services/bicycle-frame-painting/>)[Carbon Bike Repair](https://www.airtasker.com/au/services/</au/services/carbon-bicycle-repair/>)[Electric Bike Repair](https://www.airtasker.com/au/services/</au/services/electric-bicycle-repair/>)[Mobile Bicycle Repair](https://www.airtasker.com/au/services/</au/services/mobile-bicycle-repair/>)
# ## [Bricklayer](https://www.airtasker.com/au/services/</au/services/bricklaying/>)
# Need a bricklayer to build a wall, lay pavers, or just fix your letterbox? Bricks are a popular and versatile building material - everyone loves a nice, solid brick home! With the right choice of bricks and techniques, your bricks can look stylish and add value to your home. A brickie can help you get your bricklaying done faster to a professional standard so that it looks great, lasts longer, and (most importantly) is safe to use.
# ![Tasker performing a Bricklayer job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_AU/1673576308133-bricklayer-building-a-wall.jpg)
# ## [Building & Construction](https://www.airtasker.com/au/services/</au/services/building-construction/>)
# Doing your own construction work can be an exciting endeavour. However, without the necessary skills, equipment, or experience, you risk compromising your safety and the integrity of your project. Instead of tackling it yourself, why not hire experienced home builders for safer and more professional results? Whether you're looking to install a small backyard swimming pool, construct a shed or staircase, or address minor construction needs in your office space, Airtasker takes away the hassle of finding reputable builders near you.
# [Building Consultant](https://www.airtasker.com/au/services/</au/services/building-consultant/>)[Building Contractors](https://www.airtasker.com/au/services/</au/services/building-contractor/>)[Demolition](https://www.airtasker.com/au/services/</au/services/demolition/>)[Drafting](https://www.airtasker.com/au/services/</au/services/drafting/>)[Driveway Repair](https://www.airtasker.com/au/services/</au/services/driveway-repair/>)[Driveway Sealing](https://www.airtasker.com/au/services/</au/services/driveway-sealing/>)[Feature Walls](https://www.airtasker.com/au/services/</au/services/feature-wall-installation/>)[Gazebo Installation & Repair](https://www.airtasker.com/au/services/</au/services/gazebo-installation-repair/>)[General Contractors](https://www.airtasker.com/au/services/</au/services/general-contractor/>)[Office Fit Out](https://www.airtasker.com/au/services/</au/services/office-fit-out/>)[Patios](https://www.airtasker.com/au/services/</au/services/patio-contractor/>)[Pergola Installation](https://www.airtasker.com/au/services/</au/services/pergola-installation/>)[Plunge Pool](https://www.airtasker.com/au/services/</au/services/plunge-pool/>)[Shed Installation](https://www.airtasker.com/au/services/</au/services/shed-installation/>)[Staircase Renovation](https://www.airtasker.com/au/services/</au/services/staircase-renovation/>)[Swimming Pool Builders](https://www.airtasker.com/au/services/</au/services/swimming-pool-builder/>)
# ## [Business](https://www.airtasker.com/au/services/</au/services/business/>)
# Grow your business by booking business services on Airtasker! We make it easy to avail of the services your business needs to thrive. No need to endlessly search anywhere else for consulting firms who can help you run your business because you can find them all here on our platform! You can hire an experienced business consultant through Airtasker to save you time and help you level up your business. Whether you need help with planning and management, or help with business services (big or small), you’ll find the perfect business consultant near you.
# ![Tasker performing a Business job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_AU/1673576402487-business-woman-in-white.jpg)
# [Business Advisory](https://www.airtasker.com/au/services/</au/services/business-advisor/>)[Business Analysis](https://www.airtasker.com/au/services/</au/services/business-analysis/>)[Business Consultant](https://www.airtasker.com/au/services/</au/services/business-consultant/>)[Business Development](https://www.airtasker.com/au/services/</au/services/business-development/>)[Business Management](https://www.airtasker.com/au/services/</au/services/business-management/>)[Planning Consultant](https://www.airtasker.com/au/services/</au/services/planning-consultant/>)[Presentations Design](https://www.airtasker.com/au/services/</au/services/presentation-design/>)[Printing Services](https://www.airtasker.com/au/services/</au/services/printing/>)[Product Testing](https://www.airtasker.com/au/services/</au/services/product-testing/>)[Project Management](https://www.airtasker.com/au/services/</au/services/project-management/>)[Signage Designer](https://www.airtasker.com/au/services/</au/services/signage-designer/>)[Strategy Consultant](https://www.airtasker.com/au/services/</au/services/strategy-consultant/>)
# ## [Cake Delivery](https://www.airtasker.com/au/services/</au/services/cake-delivery/>)
# Any day can be extra special with a cake on the table—no need to have an actual occasion to celebrate! Whether you’re surprising a loved one, throwing an office event, or simply gifting it to yourself after a long work week, get your cake to your chosen location by enlisting the help of Taskers.
# [Gluten Free Cake Delivery](https://www.airtasker.com/au/services/</au/services/gluten-free-cake-delivery/>)[Ice Cream Cake Delivery ](https://www.airtasker.com/au/services/</au/services/ice-cream-cake-delivery/>)[Vegan Cake Delivery](https://www.airtasker.com/au/services/</au/services/vegan-cake-delivery/>)
# ## [Car Body Work](https://www.airtasker.com/au/services/</au/services/car-bodywork/>)
# From the onset of any car body damage, it's best to have an expert mechanic look into it immediately to avoid further problems from occurring.
# [Car Body Repair](https://www.airtasker.com/au/services/</au/services/car-body-repair/>)[Car Bumper Repair](https://www.airtasker.com/au/services/</au/services/car-bumper-repair/>)[Car Glass Repair](https://www.airtasker.com/au/services/</au/services/car-glass-repair/>)[Car Paint Repair](https://www.airtasker.com/au/services/</au/services/car-paint/>)[Car Respray](https://www.airtasker.com/au/services/</au/services/car-respray/>)[Car Scratch Repair](https://www.airtasker.com/au/services/</au/services/car-scratch-repair/>)[Car Welding](https://www.airtasker.com/au/services/</au/services/car-welding/>)[Car Window Tinting](https://www.airtasker.com/au/services/</au/services/car-window-tinting/>)[Car Wrapping](https://www.airtasker.com/au/services/</au/services/car-wrapping/>)[Paintless Dent Removal](https://www.airtasker.com/au/services/</au/services/paintless-dent-removal/>)[Panel Beater](https://www.airtasker.com/au/services/</au/services/panel-beater/>)[Vehicle Wraps](https://www.airtasker.com/au/services/</au/services/vehicle-wrap/>)[Windscreen Repair & Replacement](https://www.airtasker.com/au/services/</au/services/windscreen-repair-replacement/>)
# ## [Car Detailing](https://www.airtasker.com/au/services/</au/services/car-detailing/>)
# Give your car that sparkling new look by hiring a professional car detailer around you through Airtasker. With just a few clicks, you can get every nook and cranny of your vehicle scrubbed, polished, and waxed without the hassle of going to an auto detailing shop. Save your time and say goodbye to tedious price canvassing, endless garage visits, and numerous phone calls just to set an appointment!
# [Car Cleaning](https://www.airtasker.com/au/services/</au/services/car-cleaning/>)[Car Engine Steam Cleaning](https://www.airtasker.com/au/services/</au/services/car-engine-steam-cleaning/>)[Car Interior Cleaning](https://www.airtasker.com/au/services/</au/services/car-interior-cleaning/>)[Car Restoration](https://www.airtasker.com/au/services/</au/services/car-restoration/>)[Car Roof Lining Repair](https://www.airtasker.com/au/services/</au/services/car-roof-lining-repair/>)[Car Valet](https://www.airtasker.com/au/services/</au/services/car-valet/>)[Leather Car Seat Restoration](https://www.airtasker.com/au/services/</au/services/leather-car-seat-restoration/>)
# ## [Car Inspection](https://www.airtasker.com/au/services/</au/services/car-inspection/>)
# Car inspection services are a dime a dozen with numerous garages near you being able to handle the most minor of requests. However, a simple inspection can be quite expensive and may not suit the specific type you need—leading to even more costs in the end. More than that, you’ll still need to drive your car to an auto mechanic shop, which can be a danger if you aren’t registered or sure of your car’s condition.
# [Blue Slips](https://www.airtasker.com/au/services/</au/services/blue-slips/>)[Pink Slips](https://www.airtasker.com/au/services/</au/services/pink-slips/>)[Pre Purchase Car Inspection](https://www.airtasker.com/au/services/</au/services/pre-purchase/>)
# ## [Car Repair](https://www.airtasker.com/au/services/</au/services/car-repair/>)
# Getting a car repair can be costly and frustrating, especially if you're unsure of where to go. With Airtasker, you don't have to waste your time searching online for an available auto repair shop. We'll get the job done for you right in your own home, workplace, or garage! All you have to do is post your task, set the date and time, and a nearby Tasker will make their way to you for a complete mobile car repair job.
# [Alternator Repair](https://www.airtasker.com/au/services/</au/services/alternator-repair/>)[Brake Repair](https://www.airtasker.com/au/services/</au/services/brake-repair/>)[CV Shaft Replacement](https://www.airtasker.com/au/services/</au/services/cv-shaft-replacement/>)[Car Aircon Repair](https://www.airtasker.com/au/services/</au/services/car-aircon-repair/>)[Car Seat Repair](https://www.airtasker.com/au/services/</au/services/car-seat-repair/>)[Car Upholstery Repair](https://www.airtasker.com/au/services/</au/services/car-upholstery-repair/>)[Car Window Repair](https://www.airtasker.com/au/services/</au/services/car-window-repair/>)[Engine Replacement](https://www.airtasker.com/au/services/</au/services/car-engine-replacement/>)[Exhaust Repair](https://www.airtasker.com/au/services/</au/services/car-exhaust-repair/>)[Fuel Injection Repair](https://www.airtasker.com/au/services/</au/services/car-fuel-injection-repair/>)[Gearbox Repair](https://www.airtasker.com/au/services/</au/services/gearbox-repair/>)[Head Gasket Repair](https://www.airtasker.com/au/services/</au/services/head-gasket-repair/>)[Radiator Repair](https://www.airtasker.com/au/services/</au/services/car-radiator-repair/>)[Steering Wheel Repair](https://www.airtasker.com/au/services/</au/services/car-steering-wheel-repair/>)[Suspension Repair](https://www.airtasker.com/au/services/</au/services/car-suspension-repair/>)[Water Pump Repair](https://www.airtasker.com/au/services/</au/services/car-water-pump-repair/>)[Wiper Blade Replacement](https://www.airtasker.com/au/services/</au/services/car-wiper-blade-replacement/>)[Wiper Motor Repair](https://www.airtasker.com/au/services/</au/services/car-wiper-motor-repair/>)
# ## [Car Service](https://www.airtasker.com/au/services/</au/services/car-servicing/>)
# Is your car due for minor service? Or perhaps it needs something more extensive, like a major service with some repair work? Regular car servicing in line with your service schedule will ensure your car runs reliably and safely for years to come. Book a car service near you and get a mechanic with the skills, experience, and tools you need to prepare your car for the road.
# [Alfa Romeo Service](https://www.airtasker.com/au/services/</au/services/alfa-romeo-servicing/>)[Audi Service](https://www.airtasker.com/au/services/</au/services/audi-servicing/>)[BMW Service](https://www.airtasker.com/au/services/</au/services/bmw-servicing/>)[Car Delivery Service](https://www.airtasker.com/au/services/</au/services/car-delivery/>)[Fiat Service](https://www.airtasker.com/au/services/</au/services/fiat-servicing/>)[Ford Service](https://www.airtasker.com/au/services/</au/services/ford-servicing/>)[Holden Service](https://www.airtasker.com/au/services/</au/services/holden-servicing/>)[Honda Service](https://www.airtasker.com/au/services/</au/services/honda-servicing/>)[Hyundai Service](https://www.airtasker.com/au/services/</au/services/hyundai-servicing/>)[Jaguar Service](https://www.airtasker.com/au/services/</au/services/jaguar-servicing/>)[Jeep Service](https://www.airtasker.com/au/services/</au/services/jeep-servicing/>)[Kia Service](https://www.airtasker.com/au/services/</au/services/kia-servicing/>)[Land Rover Service](https://www.airtasker.com/au/services/</au/services/land-rover-servicing/>)[Lexus Service](https://www.airtasker.com/au/services/</au/services/lexus-servicing/>)[Mazda Service](https://www.airtasker.com/au/services/</au/services/mazda-servicing/>)[Mercedes-Benz Service](https://www.airtasker.com/au/services/</au/services/mercedes-benz-servicing/>)[Mini Service](https://www.airtasker.com/au/services/</au/services/mini-servicing/>)[Nissan Service](https://www.airtasker.com/au/services/</au/services/nissan-servicing/>)[Peugeot Service](https://www.airtasker.com/au/services/</au/services/peugeot-servicing/>)[Porsche Service](https://www.airtasker.com/au/services/</au/services/porsche-servicing/>)[Renault Service](https://www.airtasker.com/au/services/</au/services/renault-servicing/>)[Saab Service](https://www.airtasker.com/au/services/</au/services/saab-servicing/>)[Seat Service](https://www.airtasker.com/au/services/</au/services/seat-servicing/>)[Subaru Service](https://www.airtasker.com/au/services/</au/services/subaru-servicing/>)[Suzuki Service](https://www.airtasker.com/au/services/</au/services/suzuki-servicing/>)[Toyota Service](https://www.airtasker.com/au/services/</au/services/toyota-servicing/>)[Volkswagen Service](https://www.airtasker.com/au/services/</au/services/volkswagen-servicing/>)[Volvo Service](https://www.airtasker.com/au/services/</au/services/volvo-servicing/>)
# ## [Car Wash](https://www.airtasker.com/au/services/</au/services/car-wash/>)
# Looking for the best mobile car washing near you? There’s nothing better than a freshly washed and vacuumed car. But, like most jobs around the home, cleaning your car regularly can take a lot of time and effort. And while visiting self-service or automated car wash facilities might save you some time, it still takes you out of your way and can risk damaging your paintwork. That’s why booking an experienced mobile car washer makes perfect sense.
# ## [Carpentry](https://www.airtasker.com/au/services/</au/services/carpentry/>)
# Carpentry plays a massive part in building and construction. From the chairs we sit on to the homes we live in, so much of what we interact with has gone through the hands of a carpenter at one point.
# [Bathroom Cabinet Maker](https://www.airtasker.com/au/services/</au/services/bathroom-cabinet-maker/>)[Cabinet Design](https://www.airtasker.com/au/services/</au/services/cabinet-design/>)[Cabinet Installation](https://www.airtasker.com/au/services/</au/services/cabinet-installation/>)[Cabinet Making](https://www.airtasker.com/au/services/</au/services/cabinet-making/>)[Custom Shelving](https://www.airtasker.com/au/services/</au/services/custom-shelving/>)[Custom TV Cabinets](https://www.airtasker.com/au/services/</au/services/custom-tv-cabinet/>)[Furniture Makers](https://www.airtasker.com/au/services/</au/services/furniture-maker/>)[Kitchen Cabinet Maker](https://www.airtasker.com/au/services/</au/services/kitchen-cabinet-maker/>)[Pikler Triangle Builder](https://www.airtasker.com/au/services/</au/services/pikler-triangle-builder/>)[Refinishing](https://www.airtasker.com/au/services/</au/services/refinishing/>)[Staining](https://www.airtasker.com/au/services/</au/services/staining/>)[Timber Rot Repair](https://www.airtasker.com/au/services/</au/services/timber-rot-repair/>)[Wood Repair](https://www.airtasker.com/au/services/</au/services/wood-repair/>)[Wood Rot Treatment](https://www.airtasker.com/au/services/</au/services/wood-rot-treatment/>)
# ## [Carpet Cleaning](https://www.airtasker.com/au/services/</au/services/carpet-cleaning/>)
# Regular carpet cleaning is a must for a clean home and well-maintained carpets. But there’s no need to hire a machine, mess about with chemicals, or put your back out trying to DIY. Instead, hire a carpet cleaner service near you to take care of everything so you can enjoy that freshly cleaned carpet feeling in no time!
# ![Tasker performing a Carpet Cleaning job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_AU/1673576608574-carpet-cleaning-with-vacuum.jpg)
# ## [Cat Care](https://www.airtasker.com/au/services/</au/services/cat-care/>)
# Do you live alone and need to be away from home for long periods, leaving your beloved munchkin cat or elderly cat all alone? Then hire a cat care service on Airtasker. It’s quick, easy and convenient to get your cat the care he needs.
# [Cat Boarding](https://www.airtasker.com/au/services/</au/services/cat-boarding/>)[Cat Grooming](https://www.airtasker.com/au/services/</au/services/cat-grooming/>)[Cat Sitting](https://www.airtasker.com/au/services/</au/services/cat-sitting/>)[Cat Training](https://www.airtasker.com/au/services/</au/services/cat-training/>)
# ## [Catering](https://www.airtasker.com/au/services/</au/services/catering/>)
# It’s shocking to know how many hours and how much energy goes into preparing a delicious meal, especially for a big group of people. Don’t worry, though! Airtasker can connect you to professional catering companies in just a few taps. There’s no need to ask for recommendations or send messages to caterers for quotations.
# ...
# ![Tasker performing a Wallpapering job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.amazonaws.com/en_US/1633008773495_wallpapering.jpg)
# ## [Waste Collection & Disposal](https://www.airtasker.com/au/services/</au/services/waste-collection/>)
# Getting rid of waste takes more than simply chucking everything in the same bin. Careless disposal can harm the environment and even make people sick. For instance, batteries or leftover cleaners can contaminate the soil and seep into groundwater. Decomposing organic waste can attract pests and rodents, which can later spread diseases. Not only that—tossing reusable items means you're wasting valuable resources!
# [Bulky Waste Collection](https://www.airtasker.com/au/services/</au/services/bulky-waste-collection/>)[Commercial Waste Collection](https://www.airtasker.com/au/services/</au/services/commercial-waste-collection/>)[Food Waste Disposal](https://www.airtasker.com/au/services/</au/services/food-waste-disposal/>)[Garden Waste Collection](https://www.airtasker.com/au/services/</au/services/garden-waste-collection/>)[Green Waste Collection](https://www.airtasker.com/au/services/</au/services/green-waste-collection/>)[Household Waste Disposal](https://www.airtasker.com/au/services/</au/services/household-waste-disposal/>)[Kitchen Waste Disposal](https://www.airtasker.com/au/services/</au/services/kitchen-waste-disposal/>)[Waste Bag Collection](https://www.airtasker.com/au/services/</au/services/waste-bag-collection/>)
# ## [Waterproofing](https://www.airtasker.com/au/services/</au/services/waterproofing/>)
# Waterproofing is crucial to protect your property from water issues, structural damage, mould growth, peeling paint, and financial burden from unexpected home improvements. When it comes to this task, hiring a waterproofer near you who has in-depth knowledge of Australian standards, climate conditions, and construction practices is the way to go.
# [Wall Waterproofing](https://www.airtasker.com/au/services/</au/services/wall-waterproofing/>)
# ## [Web](https://www.airtasker.com/au/services/</au/services/web/>)
# Whether you’re launching your first website or revamping an existing one, it's best to entrust your digital space to a seasoned and reliable web developer. Your website is your official residence on the World Wide Web, so hire an expert who understands how to make it stand out and attract potential clients while keeping your data secure. Use Airtasker to connect with qualified web developers near you.
# ![Tasker performing a Web job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.ap-southeast-2.amazonaws.com/en_AU/1670211162466_tasker_and_van.jpg)
# [Bootstrap Developer](https://www.airtasker.com/au/services/</au/services/bootstrap-developer/>)[CMS Developer](https://www.airtasker.com/au/services/</au/services/cms-developer/>)[CSS Developer](https://www.airtasker.com/au/services/</au/services/css-developer/>)[Database Developer](https://www.airtasker.com/au/services/</au/services/database-developer/>)[HTML Developer](https://www.airtasker.com/au/services/</au/services/html-developer/>)[Joomla Developer](https://www.airtasker.com/au/services/</au/services/joomla-developer/>)[Magento Developer](https://www.airtasker.com/au/services/</au/services/magento/>)[MySQL Developer](https://www.airtasker.com/au/services/</au/services/mysql-developer/>)[Opencart Help](https://www.airtasker.com/au/services/</au/services/opencart/>)[PHP Developer](https://www.airtasker.com/au/services/</au/services/php-developer/>)[Programming](https://www.airtasker.com/au/services/</au/services/programming/>)[Ruby Developer](https://www.airtasker.com/au/services/</au/services/ruby-developer/>)[SQL Developer](https://www.airtasker.com/au/services/</au/services/sql-developer/>)[Shopify Developer](https://www.airtasker.com/au/services/</au/services/shopify/>)[VBA Developer](https://www.airtasker.com/au/services/</au/services/vba-developer/>)[Web Design & Development](https://www.airtasker.com/au/services/</au/services/web-design/>)[Web Hosting](https://www.airtasker.com/au/services/</au/services/web-hosting/>)[Website & App Testing](https://www.airtasker.com/au/services/</au/services/website-and-app-testing/>)[Weebly Help](https://www.airtasker.com/au/services/</au/services/weebly/>)[Wix Help](https://www.airtasker.com/au/services/</au/services/wix/>)[jQuery Developer](https://www.airtasker.com/au/services/</au/services/jquery-developer/>)
# ## [Wedding](https://www.airtasker.com/au/services/</au/services/wedding-services/>)
# The perfect wedding doesn’t have to cost you a fortune. It’s easy to find affordable and quality wedding services through Airtasker. Whether you need someone to plan your entire wedding or put up the decorations, we’ll connect you with a Tasker for the job! Set your budget and get free quotes from rated and reviewed wedding services on our platform.
# [Destination Wedding Photographer](https://www.airtasker.com/au/services/</au/services/destination-wedding-photographers/>)[Documentary Wedding Photographer](https://www.airtasker.com/au/services/</au/services/documentary-wedding-photographers/>)[Engagement Photographer](https://www.airtasker.com/au/services/</au/services/engagement-photographer/>)[Wedding Band Hire](https://www.airtasker.com/au/services/</au/services/wedding-band-hire/>)[Wedding Caterer](https://www.airtasker.com/au/services/</au/services/wedding-caterer/>)[Wedding Celebrant](https://www.airtasker.com/au/services/</au/services/wedding-celebrant/>)[Wedding DJ](https://www.airtasker.com/au/services/</au/services/wedding-dj/>)[Wedding Decorator](https://www.airtasker.com/au/services/</au/services/wedding-decorator/>)[Wedding Dress Designer](https://www.airtasker.com/au/services/</au/services/wedding-dress-designer/>)[Wedding Entertainment](https://www.airtasker.com/au/services/</au/services/wedding-entertainment/>)[Wedding Hair Stylist](https://www.airtasker.com/au/services/</au/services/wedding-hair-stylist/>)[Wedding Invitation Designer](https://www.airtasker.com/au/services/</au/services/wedding-invitation-designer/>)[Wedding Musicians](https://www.airtasker.com/au/services/</au/services/wedding-musician/>)[Wedding Photographers](https://www.airtasker.com/au/services/</au/services/wedding-photographer/>)[Wedding Singers](https://www.airtasker.com/au/services/</au/services/wedding-singer/>)[Wedding Transportation](https://www.airtasker.com/au/services/</au/services/wedding-bus-hire/>)[Wedding Videographer](https://www.airtasker.com/au/services/</au/services/wedding-videographer/>)
# ## [Wheel & Tyre Service](https://www.airtasker.com/au/services/</au/services/wheel-tyre-service/>)
# Airtasker makes it easier for you to find a reliable tyre service near your area, whether you're dealing with a flat tyre or need an emergency wheel replacement before going on a long drive. Just let Taskers know the current state of your tyres, and they'll quickly come to your rescue as soon as the need arises. If you're stuck in the middle of the road, or you're unable to leave your home or office, our mobile tyre repair service is your best bet so you won't have to risk using your vehicle to go to an auto repair shop.
# [Alloy Wheel Repair](https://www.airtasker.com/au/services/</au/services/alloy-wheel-repair/>)[Tyre Fitting](https://www.airtasker.com/au/services/</au/services/tyre-fitting/>)[Tyre Repair](https://www.airtasker.com/au/services/</au/services/car-tyre-repair/>)[Wheel Alignment](https://www.airtasker.com/au/services/</au/services/wheel-alignment/>)[Wheel Refurbishment](https://www.airtasker.com/au/services/</au/services/wheel-refurbishment/>)[Wheel Tracking](https://www.airtasker.com/au/services/</au/services/wheel-tracking/>)
# ## [Window Cleaning](https://www.airtasker.com/au/services/</au/services/window-cleaning/>)
# Is it time to book a window cleaner near you? Investing in a professional window cleaner can save you hours, plus they’ll supply all the cleaning supplies needed to get your windows shining. Whether you need a domestic or specialist glass cleaning, you’ll get a better result if you leave it up to a professionals on Airtasker.
# ![Tasker performing a Window Cleaning job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.ap-southeast-2.amazonaws.com/en_AU/1670211162466_tasker_and_van.jpg)
# ## [Windows & Doors](https://www.airtasker.com/au/services/</au/services/windows-doors/>)
# You may find many windows and doors services from various websites out there, but not all of them provide customer reviews. For this reason, choosing a reliable handyman could boil down to trusting a company’s word and following your gut. With Airtasker, you can skip the guesswork and hassle!
# [Dog Door Installation](https://www.airtasker.com/au/services/</au/services/dog-door-installation/>)[Door Hanging](https://www.airtasker.com/au/services/</au/services/door-hanging/>)[Door Repair](https://www.airtasker.com/au/services/</au/services/door-repair/>)[Garage Door Installation](https://www.airtasker.com/au/services/</au/services/garage-door-installation/>)[Garage Door Repair](https://www.airtasker.com/au/services/</au/services/garage-door-repair/>)[Window Sash Repair](https://www.airtasker.com/au/services/</au/services/window-sash-repair/>)
# ## [Writing](https://www.airtasker.com/au/services/</au/services/writing/>)
# Content can be one of the most effective ways to earn new business on the internet. By consistently entertaining or educating your audience and offering something to them for free – whether that be a blog, an instructional, an infographic or a video – you’ll attract a large and engaged following to whom you can directly advertise. You can also build brand ambassadors – people who will actively tell others about how fantastic your company is.
# ![Tasker performing a Writing job.](https://images.airtasker.com/v7/https://airtasker-seo-assets-prod.s3.ap-southeast-2.amazonaws.com/en_AU/1670211162466_tasker_and_van.jpg)
# [Academic Writing](https://www.airtasker.com/au/services/</au/services/academic-writing/>)[Article Writing](https://www.airtasker.com/au/services/</au/services/article-writing/>)[Blog Writing](https://www.airtasker.com/au/services/</au/services/blog-writing/>)[Case Study Writing](https://www.airtasker.com/au/services/</au/services/case-study-writing/>)[Content Creation](https://www.airtasker.com/au/services/</au/services/content-creation/>)[Copywriting](https://www.airtasker.com/au/services/</au/services/copywriting/>)[Creative Writer](https://www.airtasker.com/au/services/</au/services/creative-writer/>)[Ghostwriting](https://www.airtasker.com/au/services/</au/services/ghostwriting/>)[Journalist](https://www.airtasker.com/au/services/</au/services/journalist/>)[LinkedIn Profile Writing](https://www.airtasker.com/au/services/</au/services/linkedin-profile-writing/>)[Poetry Writing](https://www.airtasker.com/au/services/</au/services/poetry-writing/>)[Press Release Writing](https://www.airtasker.com/au/services/</au/services/press-release-writing/>)[Proofreading](https://www.airtasker.com/au/services/</au/services/proofreading/>)[Proposal Writing](https://www.airtasker.com/au/services/</au/services/proposal-writing/>)[Report Writing](https://www.airtasker.com/au/services/</au/services/report-writing/>)[Resume Writing](https://www.airtasker.com/au/services/</au/services/resume-writing/>)[Selection Criteria](https://www.airtasker.com/au/services/</au/services/selection-criteria/>)[Speech Writing](https://www.airtasker.com/au/services/</au/services/speech-writing/>)[Technical Writer](https://www.airtasker.com/au/services/</au/services/technical-writer/>)[Transcription](https://www.airtasker.com/au/services/</au/services/transcription/>)[Travel Writer](https://www.airtasker.com/au/services/</au/services/travel-writer/>)[White Paper Writer](https://www.airtasker.com/au/services/</au/services/white-paper-writer/>)
# Discover
# [How it works](https://www.airtasker.com/au/services/</au/how-it-works/>)[Airtasker for business](https://www.airtasker.com/au/services/</au/airtasker-for-business/>)[Earn money](https://www.airtasker.com/au/services/</au/earn-money/>)[Side Hustle Calculator](https://www.airtasker.com/au/services/</au/earn-money/side-hustle-calculator/>)[Search jobs](https://www.airtasker.com/au/services/</au/jobs/>)[Cost Guides](https://www.airtasker.com/au/services/</au/costs/>)[Service Guides](https://www.airtasker.com/au/services/</au/guides/>)[Comparison Guides](https://www.airtasker.com/au/services/</au/comparisons/>)[Student Discount](https://www.airtasker.com/au/services/</au/lp/partners/unidays-student-discount/>)[New users FAQ](https://www.airtasker.com/au/services/<https:/support.airtasker.com/hc/en-au/>)
# Company
# [About us](https://www.airtasker.com/au/services/</au/about/>)[Careers](https://www.airtasker.com/au/services/</au/careers/>)Media enquiries[Community Guidelines](https://www.airtasker.com/au/services/</au/community-guidelines/>)[Tasker Principles](https://www.airtasker.com/au/services/</au/tasker-principles/>)[Terms and Conditions](https://www.airtasker.com/au/services/</au/terms/>)[Blog](https://www.airtasker.com/au/services/<https:/www.airtasker.com/blog/>)[Contact us](https://www.airtasker.com/au/services/<https:/support.airtasker.com/hc/en-au/requests/new>)[Privacy policy](https://www.airtasker.com/au/services/</au/privacy/>)[Investors](https://www.airtasker.com/au/services/<https:/www.airtasker.automic.com.au/investor-services>)
# Existing Members
# [Post a task](https://www.airtasker.com/au/services/</post-task/>)[Browse tasks](https://www.airtasker.com/au/services/</tasks/>)[Login](https://www.airtasker.com/au/services/<#>)[Support centre](https://www.airtasker.com/au/services/<https:/support.airtasker.com/hc/en-au/>)
# Popular Categories
# [Handyman Services](https://www.airtasker.com/au/services/</au/services/handyman/>)[Cleaning Services](https://www.airtasker.com/au/services/</au/services/cleaning/>)[Delivery Services](https://www.airtasker.com/au/services/</au/services/delivery/>)[Removalists](https://www.airtasker.com/au/services/</au/services/removals/>)[Gardening Services](https://www.airtasker.com/au/services/</au/services/gardening/>)[Auto Electricians](https://www.airtasker.com/au/services/</au/services/auto-electrician/>)[Assembly Services](https://www.airtasker.com/au/services/</au/services/assembly/>)[All Services](https://www.airtasker.com/au/services/</au/services/>)
# Popular Locations
# [Sydney](https://www.airtasker.com/au/services/</au/locations/sydney/>)[Melbourne](https://www.airtasker.com/au/services/</au/locations/melbourne/>)[Brisbane](https://www.airtasker.com/au/services/</au/locations/brisbane/>)[Perth](https://www.airtasker.com/au/services/</au/locations/perth/>)[Adelaide](https://www.airtasker.com/au/services/</au/locations/adelaide/>)[Newcastle](https://www.airtasker.com/au/services/</au/locations/newcastle/>)[Canberra](https://www.airtasker.com/au/services/</au/locations/canberra/>)
# ![Promotional Visa Cash App Racing Bulls Logo with Airtasker Logo](https://images.airtasker.com/v7/www.airtasker.com/static/assets/493a4f6fc4ed2a2f.png)
# Airtasker Limited 2011-2025 ©, All rights reserved
# [![Apple store](https://www.airtasker.com/images/homepage/apple-store-2022.svg)](https://www.airtasker.com/au/services/<https:/itunes.apple.com/au/app/airtasker/id512137061?mt=8>)[![Google play](https://www.airtasker.com/images/homepage/google-play-2022.svg)](https://www.airtasker.com/au/services/<https:/play.google.com/store/apps/details?id=au.com.airtasker>)
# [](https://www.airtasker.com/au/services/<https:/www.facebook.com/Airtasker/>)[](https://www.airtasker.com/au/services/<https:/www.instagram.com/airtasker>)[](https://www.airtasker.com/au/services/<https:/www.tiktok.com/@airtasker>)
# Airtasker Limited 2011-2025 ©, All rights reserved

# %%
from pydantic import BaseModel, Field
from typing import List
import asyncio

import nest_asyncio

nest_asyncio.apply()

import json

from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode
from crawl4ai.extraction_strategy import LLMExtractionStrategy
from crawl4ai.async_configs import LLMConfig

# %%
class Taxonomy(BaseModel):
    category: str
    subcategory: str

async def main():
    # 1. Define the LLM extraction strategy
    llm_strategy = LLMExtractionStrategy(
        llm_config = LLMConfig(provider="openai/gpt-4o-mini", api_token="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"),
        schema=Taxonomy.model_json_schema(), # Or use model_json_schema()
        extraction_type="schema",
        instruction="Extract all categories and subcategories from the web page",
        chunk_token_threshold=1000,
        overlap_rate=0.0,
        apply_chunking=True,
        input_format="markdown",   # or "html", "fit_markdown"
        extra_args={"temperature": 0.0, "max_tokens": 800}
    )

    # 2. Build the crawler config
    crawl_config = CrawlerRunConfig(
        extraction_strategy=llm_strategy,
        cache_mode=CacheMode.BYPASS
    )

    # 3. Create a browser config if needed
    browser_cfg = BrowserConfig(headless=True)

    async with AsyncWebCrawler(config=browser_cfg) as crawler:
        # 4. Let's say we want to crawl a single page
        result = await crawler.arun(
            url="https://www.airtasker.com/au/services/",
            config=crawl_config
        )

        if result.success:
            # 5. The extracted content is presumably JSON
            data = json.loads(result.extracted_content)
            print("Extracted items:", data)

            # 6. Show usage stats
            llm_strategy.show_usage()  # prints token usage
        else:
            print("Error:", result.error_message)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# [INIT].... → Crawl4AI 0.5.0.post8
# [FETCH]... ↓ https://www.airtasker.com/au/services/... | Status: True | Time: 1.26s
# [SCRAPE].. ◆ https://www.airtasker.com/au/services/... | Time: 0.224s
# [EXTRACT]. ■ Completed for https://www.airtasker.com/au/services/... | Time: 48.53760895799496s
# [COMPLETE] ● https://www.airtasker.com/au/services/... | Status: True | Total: 50.04s
# Extracted items: [{'index': 1, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 0, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 2, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 3, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 5, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 6, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 4, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 7, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 8, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 9, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}, {'index': 10, 'error': True, 'tags': ['error'], 'content': "'str' object has no attribute 'choices'"}]
#
# === Token Usage Summary ===
# Type                   Count
# ------------------------------
# Completion             8,800
# Prompt                50,365
# Total                 59,165
#
# === Usage History ===
# Request #    Completion       Prompt        Total
# ------------------------------------------------
# 1                   800        4,142        4,942
# 2                   800        4,281        5,081
# 3                   800        4,255        5,055
# 4                   800        5,349        6,149
# 5                   800        4,253        5,053
# 6                   800        5,152        5,952
# 7                   800        4,869        5,669
# 8                   800        4,938        5,738
# 9                   800        4,608        5,408
# 10                  800        4,264        5,064
# 11                  800        4,254        5,054

# %%
# %pip install --quiet -U langchain-scrapegraph
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import getpass
import os

if not os.environ.get("SGAI_API_KEY"):
    os.environ["SGAI_API_KEY"] = getpass.getpass("ScrapeGraph AI API key:\n")

# %%
from langchain_scrapegraph.tools import (
    GetCreditsTool,
    MarkdownifyTool,
    SmartScraperTool,
)

smartscraper = SmartScraperTool()
markdownify = MarkdownifyTool()
credits = GetCreditsTool()

# %%
# SmartScraper
result = smartscraper.invoke(
    {
        "user_prompt": "Extract categories and subcategories from the website",
        "website_url": "https://www.airtasker.com/au/services/",
    }
)
print("SmartScraper Result:", result)
# Out:
# SmartScraper Result: {'categories': ['Accountants', 'Admin', 'Alterations', 'Appliances', 'Assembly', 'Auto Electricians', 'Bakers', 'Barbers', 'Beauticians', 'Bicycle Service', 'Bricklaying', 'Building & Construction', 'Business', 'Car Body Work', 'Car Detailing', 'Car Repair', 'Car Service', 'Carpentry', 'Cat Care', 'Catering', 'Chef', 'Cladding', 'Cleaning', 'Computers & IT', 'Concreting', 'Decking', 'Delivery', 'Design', 'Dog Care', 'Draftsman', 'Driving', 'Electricians', 'Entertainment', 'Events', 'Fencing', 'Fitness', 'Flooring', 'Florist', 'Furniture Assembly', 'Furniture Repair', 'Gardening', 'Gate Installation', 'Gift Delivery', 'Glaziers', 'Glass Services', 'Grocery Delivery', 'Hair Removal', 'Hairdressers', 'Handyman', 'Health & Wellness', 'Heating & Cooling', 'Home & Lifestyle', 'Home Automation and Security', 'Home Theatre', 'House Cleaning', 'Interior Designer', 'Kitchen Renovation', 'Kitchen Installation', 'Landscaping', 'Laundry', 'Lawn Care', 'Legal Services', 'Lessons', 'Local Mobile Mechanic', 'Locksmith', 'Makeup Artist', 'Marketing', 'Martial Arts', 'Mechanic', 'Models', 'Motorcycle Mechanic', 'Moped Repair', 'Music Lessons', 'Painting', 'Paving', 'Pest Control', 'Pet Care', 'Photographers', 'Plasterer', 'Plumbing', 'Pool Maintenance', 'Real Estate', 'Removals', 'Roofing', 'Rubbish Removal', 'Seamstress', 'Sharpening', 'Staffing', 'Surveyors', 'Swimming Lessons', 'Tailors', 'Takeaway & Delivery', 'Tattoo Artists', 'Tiling', 'Tradesman', 'Translation', 'Tree Surgeons', 'Tutoring', 'Vehicle Transport', 'Wall Hanging and Mounting', 'Wallpapering', 'Waste Collection & Disposal', 'Waterproofing', 'Web', 'Wedding', 'Wheel & Tyre Service', 'Window Cleaning', 'Windows & Doors', 'Writing', 'Gardening', 'Painting', 'Cleaning', 'Removals', 'Repairs and Installations', 'Copywriting', 'Data Entry', 'Furniture Assembly'], 'subcategories': ['Accounting', 'Admin', 'Alterations', 'Appliances', 'Architects', 'Assembly', 'Audio Visual', 'Auto Electrician', 'Bakers', 'Balloon Delivery', 'Barbers', 'Bathroom Renovation', 'Beauticians', 'Bicycle Service', 'Bricklayer', 'Building & Construction', 'Business', 'Cake Delivery', 'Car Body Work', 'Car Detailing', 'Car Inspection', 'Car Repair', 'Car Service', 'Car Wash', 'Carpentry', 'Carpet Cleaning', 'Cat Care', 'Catering', 'Chef', 'Childcare & Safety', 'Cladding', 'Cleaning', 'Clearance Services', 'Coaching', 'Coffee Delivery', 'Commercial Cleaning', 'Computers & IT', 'Concreting', 'Cooking', 'Counselling & Therapy', 'Courier Services', 'Dance Lessons', 'Decking', 'Delivery', 'Design', 'Dessert Delivery', 'Dog Care', 'Draftsman', 'Driving', 'Electricians', 'Electronic Repair', 'Engraving', 'Entertainment', 'Events', 'Fencing', 'Fitness', 'Flooring', 'Florist', 'Flower Delivery', 'Food Delivery', 'Fresh Food Delivery', 'Furniture Assembly', 'Furniture Repair', 'Gardening', 'Gate Installation', 'Gift Delivery', 'Glaziers', 'Grocery Delivery', 'Hair Removal', 'Hairdressers', 'Handyman', 'Health & Wellness', 'Heating & Cooling', 'Home & Lifestyle', 'Home Automation and Security', 'Home Theatre', 'House Cleaning', 'Interior Designer', 'Kitchen Renovation', 'Kitchen Installation', 'Landscaping', 'Laundry', 'Lawn Care', 'Legal Services', 'Lessons', 'Local Mobile Mechanic', 'Locksmith', 'Makeup Artist', 'Marketing', 'Martial Arts', 'Mechanic', 'Models', 'Motorcycle Mechanic', 'Music Lessons', 'Painting', 'Paving', 'Pest Control', 'Pet Care', 'Photographers', 'Plasterer', 'Plumbing', 'Pool Maintenance', 'Real Estate', 'Removals', 'Roofing', 'Rubbish Removal', 'Seamstress', 'Sharpening', 'Staffing', 'Surveyors', 'Swimming Lessons', 'Tailors', 'Takeaway & Delivery', 'Tattoo Artists', 'Tiling', 'Tradesman', 'Translation', 'Tree Surgeons', 'Tutoring', 'Vehicle Transport', 'Wall Hanging and Mounting', 'Wallpapering', 'Waste Collection & Disposal', 'Waterproofing', 'Web', 'Wedding', 'Wheel & Tyre Service', 'Window Cleaning', 'Windows & Doors', 'Writing', 'Car Body Repair', 'Car Detailing', 'Car  ...

# %%
result
# Out:
# {'categories': ['Accountants',
#   'Admin',
#   'Alterations',
#   'Appliances',
#   'Assembly',
#   'Auto Electricians',
#   'Bakers',
#   'Barbers',
#   'Beauticians',
#   'Bicycle Service',
#   'Bricklaying',
#   'Building & Construction',
#   'Business',
#   'Car Body Work',
#   'Car Detailing',
#   'Car Repair',
#   'Car Service',
#   'Carpentry',
#   'Cat Care',
#   'Catering',
#   'Chef',
#   'Cladding',
#   'Cleaning',
#   'Computers & IT',
#   'Concreting',
#   'Decking',
#   'Delivery',
#   'Design',
#   'Dog Care',
#   'Draftsman',
#   'Driving',
#   'Electricians',
#   'Entertainment',
#   'Events',
#   'Fencing',
#   'Fitness',
#   'Flooring',
#   'Florist',
#   'Furniture Assembly',
#   'Furniture Repair',
#   'Gardening',
#   'Gate Installation',
#   'Gift Delivery',
#   'Glaziers',
#   'Glass Services',
#   'Grocery Delivery',
#   'Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Kitchen Renovation',
#   'Kitchen Installation',
#   'Landscaping',
#   'Laundry',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Mechanic',
#   'Models',
#   'Motorcycle Mechanic',
#   'Moped Repair',
#   'Music Lessons',
#   'Painting',
#   'Paving',
#   'Pest Control',
#   'Pet Care',
#   'Photographers',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Real Estate',
#   'Removals',
#   'Roofing',
#   'Rubbish Removal',
#   'Seamstress',
#   'Sharpening',
#   'Staffing',
#   'Surveyors',
#   'Swimming Lessons',
#   'Tailors',
#   'Takeaway & Delivery',
#   'Tattoo Artists',
#   'Tiling',
#   'Tradesman',
#   'Translation',
#   'Tree Surgeons',
#   'Tutoring',
#   'Vehicle Transport',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Writing',
#   'Gardening',
#   'Painting',
#   'Cleaning',
#   'Removals',
#   'Repairs and Installations',
#   'Copywriting',
#   'Data Entry',
#   'Furniture Assembly'],
#  'subcategories': ['Accounting',
#   'Admin',
#   'Alterations',
#   'Appliances',
#   'Architects',
#   'Assembly',
#   'Audio Visual',
#   'Auto Electrician',
#   'Bakers',
#   'Balloon Delivery',
#   'Barbers',
#   'Bathroom Renovation',
#   'Beauticians',
#   'Bicycle Service',
#   'Bricklayer',
#   'Building & Construction',
#   'Business',
#   'Cake Delivery',
#   'Car Body Work',
#   'Car Detailing',
#   'Car Inspection',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Carpentry',
#   'Carpet Cleaning',
#   'Cat Care',
#   'Catering',
#   'Chef',
#   'Childcare & Safety',
#   'Cladding',
#   'Cleaning',
#   'Clearance Services',
#   'Coaching',
#   'Coffee Delivery',
#   'Commercial Cleaning',
#   'Computers & IT',
#   'Concreting',
#   'Cooking',
#   'Counselling & Therapy',
#   'Courier Services',
#   'Dance Lessons',
#   'Decking',
#   'Delivery',
#   'Design',
#   'Dessert Delivery',
#   'Dog Care',
#   'Draftsman',
#   'Driving',
#   'Electricians',
#   'Electronic Repair',
#   'Engraving',
#   'Entertainment',
#   'Events',
#   'Fencing',
#   'Fitness',
#   'Flooring',
#   'Florist',
#   'Flower Delivery',
#   'Food Delivery',
#   'Fresh Food Delivery',
#   'Furniture Assembly',
#   'Furniture Repair',
#   'Gardening',
#   'Gate Installation',
#   'Gift Delivery',
#   'Glaziers',
#   'Grocery Delivery',
#   'Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Kitchen Renovation',
#   'Kitchen Installation',
#   'Landscaping',
#   'Laundry',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Mechanic',
#   'Models',
#   'Motorcycle Mechanic',
#   'Music Lessons',
#   'Painting',
#   'Paving',
#   'Pest Control',
#   'Pet Care',
#   'Photographers',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Real Estate',
#   'Removals',
#   'Roofing',
#   'Rubbish Removal',
#   'Seamstress',
#   'Sharpening',
#   'Staffing',
#   'Surveyors',
#   'Swimming Lessons',
#   'Tailors',
#   'Takeaway & Delivery',
#   'Tattoo Artists',
#   'Tiling',
#   'Tradesman',
#   'Translation',
#   'Tree Surgeons',
#   'Tutoring',
#   'Vehicle Transport',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Writing',
#   'Car Body Repair',
#   'Car Detailing',
#   'Car Cleaning',
#   'Car Inspection',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Carpentry',
#   'Carpet Cleaning',
#   'Cat Care',
#   'Catering',
#   'Chef',
#   'Childcare & Safety',
#   'Cladding',
#   'Cleaning',
#   'Clearance Services',
#   'Coaching',
#   'Coffee Delivery',
#   'Commercial Cleaning',
#   'Computers & IT',
#   'Concreting',
#   'Cooking',
#   'Counselling & Therapy',
#   'Courier Services',
#   'Dance Lessons',
#   'Decking',
#   'Delivery',
#   'Design',
#   'Dessert Delivery',
#   'Dog Care',
#   'Draftsman',
#   'Driving',
#   'Electricians',
#   'Electronic Repair',
#   'Engraving',
#   'Entertainment',
#   'Events',
#   'Fencing',
#   'Fitness',
#   'Flooring',
#   'Florist',
#   'Food Delivery',
#   'Furniture Assembly',
#   'Furniture Repair',
#   'Gardening',
#   'Gate Installation',
#   'Gift Delivery',
#   'Glaziers',
#   'Glass Services',
#   'Grocery Delivery',
#   'Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Kitchen Renovation',
#   'Kitchen Installation',
#   'Landscaping',
#   'Laundry',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Mechanic',
#   'Models',
#   'Motorcycle Mechanic',
#   'Music Lessons',
#   'Painting',
#   'Paving',
#   'Pest Control',
#   'Pet Care',
#   'Photographers',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Real Estate',
#   'Removals',
#   'Roofing',
#   'Rubbish Removal',
#   'Seamstress',
#   'Sharpening',
#   'Staffing',
#   'Surveyors',
#   'Swimming Lessons',
#   'Tailors',
#   'Takeaway & Delivery',
#   'Tattoo Artists',
#   'Tiling',
#   'Tradesman',
#   'Translation',
#   'Tree Surgeons',
#   'Tutoring',
#   'Vehicle Transport',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Writing',
#   'Arborist',
#   'Tutoring',
#   'Vehicle Transport',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Writing',
#   'Dance Lessons',
#   'Decking',
#   'Delivery',
#   'Design',
#   'Dessert Delivery',
#   'Dog Care',
#   'Draftsman',
#   'Driving',
#   'Electricians',
#   'Electronic Repair',
#   'Engraving',
#   'Entertainment',
#   'Events',
#   'Fencing',
#   'Fitness',
#   'Flooring',
#   'Florist',
#   'Food Delivery',
#   'Furniture Assembly',
#   'Furniture Repair',
#   'Gardening',
#   'Gate Installation',
#   'Gift Delivery',
#   'Glaziers',
#   'Glass Services',
#   'Grocery Delivery',
#   'Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Kitchen Renovation',
#   'Kitchen Installation',
#   'Landscaping',
#   'Laundry',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Mechanic',
#   'Models',
#   'Motorcycle Mechanic',
#   'Music Lessons',
#   'Painting',
#   'Paving',
#   'Pest Control',
#   'Pet Care',
#   'Photographers',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Real Estate',
#   'Removals',
#   'Roofing',
#   'Rubbish Removal',
#   'Seamstress',
#   'Sharpening',
#   'Staffing',
#   'Surveyors',
#   'Swimming Lessons',
#   'Tailors',
#   'Takeaway & Delivery',
#   'Tattoo Artists',
#   'Tiling',
#   'Tradesman',
#   'Translation',
#   'Tree Surgeons',
#   'Tutoring',
#   'Vehicle Transport',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Writing',
#   'Car Body Repair',
#   'Car Detailing',
#   'Car Cleaning',
#   'Car Inspection',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Carpentry',
#   'Carpet Cleaning',
#   'Cat Care',
#   'Catering',
#   'Chef',
#   'Childcare & Safety',
#   'Cladding',
#   'Cleaning',
#   'Clearance Services',
#   'Coaching',
#   'Coffee Delivery',
#   'Commercial Cleaning',
#   'Computers & IT',
#   'Concreting',
#   'Cooking',
#   'Counselling & Therapy',
#   'Courier Services',
#   'Dance Lessons',
#   'Decking',
#   'Delivery',
#   'Design',
#   'Dessert Delivery',
#   'Dog Care',
#   'Draftsman',
#   'Driving',
#   'Electricians',
#   'Electronic Repair',
#   'Engraving',
#   'Entertainment',
#   'Events',
#   'Fencing',
#   'Fitness',
#   'Flooring',
#   'Florist',
#   'Food Delivery',
#   'Furniture Assembly',
#   'Furniture Repair',
#   'Gardening',
#   'Gate Installation',
#   'Gift Delivery',
#   'Glaziers',
#   'Glass Services',
#   'Grocery Delivery',
#   'Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Kitchen Renovation',
#   'Kitchen Installation',
#   'Landscaping',
#   'Laundry',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Mechanic',
#   'Models',
#   'Motorcycle Mechanic',
#   'Music Lessons',
#   'Painting',
#   'Paving',
#   'Pest Control',
#   'Pet Care',
#   'Photographers',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Real Estate',
#   'Removals',
#   'Roofing',
#   'Rubbish Removal',
#   'Seamstress',
#   'Sharpening',
#   'Staffing',
#   'Surveyors',
#   'Swimming Lessons',
#   'Tailors',
#   'Takeaway & Delivery',
#   'Tattoo Artists',
#   'Tiling',
#   'Tradesman',
#   'Translation',
#   'Tree Surgeons',
#   'Tutoring',
#   'Vehicle Transport',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Writing',
#   'Digital ID Badge',
#   'Police Check Badge',
#   'Billing Address',
#   'Notification Settings',
#   'Community Guidelines',
#   'Tasker Principles',
#   'Airtasker Insurance',
#   'Legal',
#   'Digital ID Description',
#   'Digital ID Requirements',
#   'Police Verification',
#   'Billing Address Form',
#   'Notification Settings',
#   'Community Guidelines',
#   'Tasker Principles',
#   'Airtasker Insurance',
#   'Legal Terms and Conditions',
#   'Legal Community Guidelines',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel',
#   'Walk my doggo']}

# %%
taxo = {}

for category in result.get("categories"):
    print(category)
    # SmartScraper
    result1 = smartscraper.invoke(
        {
            "user_prompt": "Extract all the subcategories of the category: " + category + " from the website ",
            "website_url": "https://www.airtasker.com/au/services/",
        }
    )



    taxo[category] = result1.get('subcategories')
# Out:
# Accountants
# Admin
# Alterations
# Appliances
# Assembly
# Auto Electricians
# Bakers
# Barbers
# Beauticians
# Bicycle Service
# Bricklaying
# Building & Construction
# Business
# Car Body Work
# Car Detailing
# Car Repair
# Car Service
# Carpentry
# Cat Care
# Catering
# Chef
# Cladding
# Cleaning
# Computers & IT
# Concreting
# Decking
# Delivery
# Design
# Dog Care
# Draftsman
# Driving
# Electricians
# Entertainment
# Events
# Fencing
# Fitness
# Flooring
# Florist
# Furniture Assembly
# Furniture Repair
# Gardening
# Gate Installation
# Gift Delivery
# Glaziers
# Glass Services
# Grocery Delivery
# Hair Removal
# Hairdressers
# Handyman
# Health & Wellness
# Heating & Cooling
# Home & Lifestyle
# Home Automation and Security
# Home Theatre
# House Cleaning
# Interior Designer
# Kitchen Renovation
# Kitchen Installation
# Landscaping
# Laundry
# Lawn Care
# Legal Services
# Lessons
# Local Mobile Mechanic
# Locksmith
# Makeup Artist
# Marketing
# Martial Arts
# Mechanic
# Models
# Motorcycle Mechanic
# Moped Repair
# Music Lessons
# Painting
# Paving
# Pest Control
# Pet Care
# Photographers
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 6
#       4 print(category)
#       5 # SmartScraper
# ----> 6 result1 = smartscraper.invoke(
#       7     {
#       8         "user_prompt": "Extract all the subcategories of the category: " + category + " from the website ",
#       9         "website_url": "https://www.airtasker.com/au/services/",
#      10     }
#      11 )
#      15 taxo[category] = result1.get('subcategories')
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/langchain_core/tools/base.py:508, in BaseTool.invoke(self, input, config, **kwargs)
#     501 def invoke(
#     502     self,
#     503     input: Union[str, dict, ToolCall],
#     504     config: Optional[RunnableConfig] = None,
#     505     **kwargs: Any,
#     506 ) -> Any:
#     507     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 508     return self.run(tool_input, **kwargs)
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/langchain_core/tools/base.py:763, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     761 if error_to_raise:
#     762     run_manager.on_tool_error(error_to_raise)
# --> 763     raise error_to_raise
#     764 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     765 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/langchain_core/tools/base.py:732, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     730     if config_param := _get_runnable_config_param(self._run):
#     731         tool_kwargs = tool_kwargs | {config_param: config}
# --> 732     response = context.run(self._run, *tool_args, **tool_kwargs)
#     733 if self.response_format == "content_and_artifact":
#     734     if not isinstance(response, tuple) or len(response) != 2:
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/langchain_scrapegraph/tools/smartscraper.py:146, in SmartScraperTool._run(self, user_prompt, website_url, website_html, run_manager)
#     143     raise ValueError("Client not initialized")
#     145 if self.llm_output_schema is None:
# --> 146     response = self.client.smartscraper(
#     147         website_url=website_url,
#     148         user_prompt=user_prompt,
#     149         website_html=website_html,
#     150     )
#     151 elif isinstance(self.llm_output_schema, type) and issubclass(
#     152     self.llm_output_schema, BaseModel
#     153 ):
#     154     response = self.client.smartscraper(
#     155         website_url=website_url,
#     156         user_prompt=user_prompt,
#     157         website_html=website_html,
#     158         output_schema=self.llm_output_schema,
#     159     )
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/scrapegraph_py/client.py:205, in Client.smartscraper(self, user_prompt, website_url, website_html, headers, output_schema)
#     196 request = SmartScraperRequest(
#     197     website_url=website_url,
#     198     website_html=website_html,
#    (...)
#     201     output_schema=output_schema,
#     202 )
#     203 logger.debug("✅ Request validation passed")
# --> 205 result = self._make_request(
#     206     "POST", f"{API_BASE_URL}/smartscraper", json=request.model_dump()
#     207 )
#     208 logger.info("✨ Smartscraper request completed successfully")
#     209 return result
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/scrapegraph_py/client.py:123, in Client._make_request(self, method, url, **kwargs)
#     120 logger.info(f"🚀 Making {method} request to {url}")
#     121 logger.debug(f"🔍 Request parameters: {kwargs}")
# --> 123 response = self.session.request(method, url, timeout=self.timeout, **kwargs)
#     124 logger.debug(f"📥 Response status: {response.status_code}")
#     126 result = handle_sync_response(response)
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniforge3/envs/yomap/lib/python3.10/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/miniforge3/envs/yomap/lib/python3.10/http/client.py:1368, in HTTPConnection.getresponse(self)
#    1366 try:
#    1367     try:
# -> 1368         response.begin()
#    1369     except ConnectionError:
#    1370         self.close()
#
# File ~/miniforge3/envs/yomap/lib/python3.10/http/client.py:317, in HTTPResponse.begin(self)
#     315 # read until we get a non-100 response
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#     319         break
#
# File ~/miniforge3/envs/yomap/lib/python3.10/http/client.py:278, in HTTPResponse._read_status(self)
#     277 def _read_status(self):
# --> 278     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     279     if len(line) > _MAXLINE:
#     280         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/yomap/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniforge3/envs/yomap/lib/python3.10/ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/yomap/lib/python3.10/ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
taxo
# Out:
# {'Accountants': ['Budgeting Help',
#   'Financial Advisor',
#   'Financial Modelling',
#   'Financial Planning',
#   'Financial Reporting',
#   'MYOB Training',
#   'Mortgage Advisor',
#   'Pension Advisor',
#   'Tax Advisor',
#   'XERO Training',
#   'Accounting Tutor',
#   'Algebra Tutor',
#   'Art Tutor',
#   'Biochemistry Tutor',
#   'Biology Tutor',
#   'Calligraphy Tutor',
#   'Chemistry Tutor',
#   'Chinese Tutor',
#   'Economics Tutor',
#   'Elocution Lessons',
#   'Engineering Tutor',
#   'English Tutor',
#   'Environment Science Tutor',
#   'French Tutor',
#   'GMAT Tutor',
#   'German Tutor',
#   'History Tutor',
#   'Italian Tutor',
#   'Japanese Tutor',
#   'Korean Lessons',
#   'Language Tutor',
#   'Mandarin Tutor',
#   'Maths Tutor',
#   'Physics Tutor',
#   'Portuguese Tutor',
#   'Public Speaking',
#   'Python Tutor',
#   'Science Tutor',
#   'Spanish Lessons',
#   'University Tutor'],
#  'Admin': ['Data Entry',
#   'Document Filing',
#   'HR Services',
#   'Office Work',
#   'Personal Assistant',
#   'Research Assistant',
#   'Typist',
#   'Virtual Assistant',
#   'eBay Selling Assistance',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel',
#   'Walk my doggo'],
#  'Alterations': ['Wedding Dress Alterations',
#   'Zipper Repair',
#   'Alternator Repair',
#   'Brake Repair',
#   'CV Shaft Replacement',
#   'Car Aircon Repair',
#   'Car Seat Repair',
#   'Car Upholstery Repair',
#   'Car Window Repair',
#   'Engine Replacement',
#   'Exhaust Repair',
#   'Fuel Injection Repair',
#   'Gearbox Repair',
#   'Head Gasket Repair',
#   'Radiator Repair',
#   'Steering Wheel Repair',
#   'Suspension Repair',
#   'Water Pump Repair',
#   'Wiper Blade Replacement',
#   'Wiper Motor Repair'],
#  'Appliances': ['Appliance Installation',
#   'Appliance Repair',
#   'Bosch Appliance Repair',
#   'Coffee Machine Repairs',
#   'Cooker Hood Installation & Repair',
#   'Cooktop Installation',
#   'Dishdrawer Installation',
#   'Dishwasher Not Draining',
#   'Dishwasher Repair',
#   'Dryer Installation',
#   'Freezer Installation',
#   'Fridge Repair & Installation',
#   'Gas Fitters',
#   'Gas Oven Repair and Installation',
#   'Gas Stove Installation & Repair',
#   'Ice Machine Repair & Installation',
#   'Microwave Repair',
#   'Oven Fan Repair',
#   'Oven Repair',
#   'Rangehood Installation',
#   'Rangehood Repairs',
#   'Samsung Fridge Repair',
#   'Stove Connection',
#   'Stove Installation',
#   'Vacuum Cleaner Repair',
#   'Washing Machine Levelling',
#   'Washing Machine Repairs & Installation',
#   'Attic Ladder Installation',
#   'Awning Repair',
#   'BBQ Repair',
#   'Bed Repairs',
#   'Bistro Blind Installation',
#   'Blind Repairs',
#   'Blueboard Installation',
#   'Bunnings Shed Installation',
#   'Cafe Blinds Installation',
#   'Cat Door Installation',
#   'Ceiling Fan Installation',
#   'Ceiling Fan Repair',
#   'Cement Sheeting Installation',
#   'Chainsaw Service & Repair',
#   'Chandelier Installation',
#   'Chicken Coops',
#   'Chicken Runs',
#   'Clock Repair',
#   'Clothesline Installation',
#   'Coffee Table Repair',
#   'Conservatory Repairs',
#   'Cornice Repair',
#   'Cot Repair',
#   'Curtain Rod Installation',
#   'Curtains & Blinds Fitter',
#   'Custom Mailboxes',
#   'Dining Chair Repair',
#   'Dog House Builder',
#   'Door Frame Installation',
#   'Door Installation',
#   'Door Knob Installation',
#   'Drone Recovery',
#   'Fireplace Installation',
#   'Fitness Equipment Installation',
#   'Flyscreen Installation',
#   'Garden Shed Installation & Repair',
#   'General Labour',
#   'Gyprock Installation',
#   'Hills Hoist Removal',
#   'Home Gym Repair',
#   'Hot Tub Repair',
#   'IKEA Benchtop Installation',
#   'Internal Door Installation',
#   'Jack of all Trades',
#   'Kaboodle Kitchen Installation',
#   'Kitchen Cupboard Repair',
#   'Kitchen Drawer Repair',
#   'Kitchen Sink Installation',
#   'Lattice Installation',
#   'Laundry Tub Installation',
#   'Letterbox Replacement',
#   'Lounge Repair',
#   'MDF Cutting',
#   'MDF Installation',
#   'Mirror Cutting',
#   'Mirror Repair',
#   'Office Chair Repair',
#   'Outdoor Blinds Installation',
#   'Patio Sliding Door Repair',
#   'Pet Door Installation',
#   'Pool Table Refelting',
#   'Pressure Washer Repair',
#   'Privacy Screens',
#   'Property Maintenance',
#   'Recliner Repair',
#   'Render Repair',
#   'Ring Doorbell Installation',
#   'Roller Shutter Blinds Repair & Installation',
#   'Roman Blinds Installation',
#   'Screen Door Hinge Repairs',
#   'Sewing Machine Repair',
#   'Shower Screen Installation',
#   'Sign Hanging',
#   'Signage Installers',
#   'Sink Installation',
#   'Sliding Door Repair',
#   'Sofa Bed Repairs',
#   'Soundproofing',
#   'Table Lamp Repair',
#   'Table Tennis Table Repair',
#   'Tent Repair',
#   'Toilet Seat Fitting',
#   'Tool Repair',
#   'Trampoline Repair Service',
#   'Treadmill Repair',
#   'Vanity Mirror Installation',
#   'Venetian Blind Repair',
#   'Villaboard Installation',
#   'Water Tank Installation & Repair',
#   'Weather Stripping',
#   'Weatherboard Repair',
#   'Window Frame Repair',
#   'Window Repair',
#   'Wooden Blind Fitter',
#   'Appliance Removal',
#   'Backloading',
#   'Brisbane to Sydney Removals',
#   'Fitness Equipment Removals',
#   'Fragile Item Removal',
#   'Fridge Removal',
#   'Furniture Removal',
#   'Heavy Lifting',
#   'Hot Tub Removal',
#   'House Removal',
#   'Interstate Removals',
#   'Mattress Removal',
#   'Melbourne to Sydney Removals',
#   'MoveCube',
#   'Piano Removals',
#   'Pool Table Removals',
#   'Shed Removal',
#   'Sofa Removal & Disposal',
#   'Spa Removal',
#   'Sydney to Brisbane Removals',
#   'Sydney to Melbourne Removals',
#   'Taxibox',
#   'Treadmill Removal',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel',
#   'Walk my doggo'],
#  'Assembly': ['BBQ Assembly',
#   'Basketball Hoop System Assembly',
#   'Bunnings Assembly',
#   'Car Body Repair',
#   'Car Bumper Repair',
#   'Car Glass Repair',
#   'Car Paint Repair',
#   'Car Respray',
#   'Car Scratch Repair',
#   'Car Welding',
#   'Car Window Tinting',
#   'Car Wrapping',
#   'Cube Storage Assembly',
#   'Disassembly',
#   'Double Glazing',
#   'Draught Proofing',
#   'Exercise Bike Assembly',
#   'Fantastic Furniture Assembly',
#   'Fix my washing machine',
#   'Glass Cutting',
#   'Glass Repair',
#   'Harvey Norman Furniture Assembly',
#   'Help bartend my party',
#   'Help me move home',
#   'Help me with Excel',
#   'Home Gym Assembly',
#   'Inversion Table Assembly',
#   'Kids Bike Assembly',
#   'Leaded Glass Repair',
#   'Mow my backyard',
#   'Mow my lawn',
#   'Nordictrack Assembly',
#   'Paintless Dent Removal',
#   'Panel Beater',
#   'PC Assembly',
#   'Palm Tree Removal',
#   'Playground Assembly',
#   'Pool Table Assembly',
#   'Spring Free Trampoline Assembly',
#   'Swing Set Assembly',
#   'Table Tennis Table Assembly',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'Triple Glazing',
#   'Toy Assembly',
#   'Trampoline Assembly',
#   'Treadmill Assembly',
#   'Vehicle Wraps',
#   'Vuly Trampoline Assembly',
#   'Walk my doggo',
#   'Windscreen Repair & Replacement'],
#  'Auto Electricians': ['Alternator Replacement',
#   'Arborist',
#   'Bar Fridge Repairs',
#   'Brake Pad Replacement',
#   'Bull Bar Installation',
#   'Car Air Conditioning Service',
#   'Car Aircon Regas',
#   'Car Alarm System Repair',
#   'Car Battery Replacement',
#   'Car Body Repair',
#   'Car Bumper Repair',
#   'Car CD Player Installation',
#   'Car Diagnostics',
#   'Car Electrical Repair',
#   'Car Glass Repair',
#   'Car Keyless Entry System Installation',
#   'Car Paint Repair',
#   'Car Respray',
#   'Car Scratch Repair',
#   'Car Speaker Installation',
#   'Car Stereo Installation',
#   'Car Window Replacement',
#   'Car Window Tinting',
#   'Car Wrapping',
#   'Carbody Repair',
#   'Central Locking Installation',
#   'Clutch Replacement',
#   'Dash Cam Installation',
#   'Data Cable Installation',
#   'Downlights Installation',
#   'Electric Car Service',
#   'Electric Shower Installation',
#   'Electrical Inspection and Testing',
#   'Electrical Installation',
#   'Electrical Rewiring',
#   'Fan Belt Replacement',
#   'Fuel Pump Replacement',
#   'Generator Repair',
#   'Glow Plug Replacement',
#   'Head Unit Installation',
#   'Headlight Bulb Replacement',
#   'Ignition Systems Repair',
#   'Lamp Repairs',
#   'LED Lights Installation',
#   'Light Bar Installation',
#   'Light Installation',
#   'Light Repair',
#   'Mobile Auto Electrician',
#   'NBN Electrician',
#   'Oil & Filter Change',
#   'O2 Sensor Replacement',
#   'Paintless Dent Removal',
#   'Panel Beater',
#   'Parking Sensor Replacement',
#   'Power Point Installation',
#   'Reversing Camera Installation',
#   'Smoke Alarm Installation',
#   'Solar Panel Installation',
#   'Sockets and Switches Installation',
#   'Starter Motor Repair',
#   'Suspension Bushes Replacement',
#   'Telephone Engineers',
#   'Timing Belt Replacement',
#   'Tow Bar Installation',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'UHF Radio Installations',
#   'Vehicle Wraps',
#   'Water Heater Repairs and Installation',
#   'Windscreen Repair & Replacement',
#   'Winch Installation'],
#  'Bakers': ['Artisan Baker',
#   'Cake Decorators',
#   'Cake Toppers',
#   'Celebration Cakes',
#   'Custom Birthday Cakes',
#   'Custom Cakes',
#   'French Baker',
#   'Gluten Free Baker',
#   'Greek Baker',
#   'Japanese Baker',
#   'Keto Baker',
#   'Personalised Cupcakes',
#   'Vegan Baker',
#   'Wedding Cakes',
#   'Wholesale Baker',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel',
#   'Walk my doggo'],
#  'Barbers': ['Beard Grooming', 'Mobile Barbers'],
#  'Beauticians': ['Eyebrow Microblading',
#   'Eyebrow Threading',
#   'Eyebrow Waxing',
#   'Eyelash Extensions',
#   'Eyelash Lift and Tint',
#   'Eyelash Perming',
#   'Facial Hair Removal',
#   "Ladies' Bikini Waxing",
#   'Manicure',
#   'Mobile Waxing',
#   'Nail Technicians',
#   'Pedicure',
#   'Spray Tanning',
#   'Waxing'],
#  'Bicycle Service': ['Bicycle Assembly',
#   'Bicycle Courier',
#   'Bicycle Tyre Repair',
#   'Bike Frame Painting Service',
#   'Carbon Bike Repair',
#   'Electric Bike Repair',
#   'Mobile Bicycle Repair'],
#  'Bricklaying': ['Bricklayer', 'Brick Fencing'],
#  'Building & Construction': ['Building Consultant',
#   'Building Contractors',
#   'Demolition',
#   'Drafting',
#   'Driveway Repair',
#   'Driveway Sealing',
#   'Feature Walls',
#   'Gazebo Installation & Repair',
#   'General Contractors',
#   'Office Fit Out',
#   'Patios',
#   'Pergola Installation',
#   'Plunge Pool',
#   'Shed Installation',
#   'Staircase Renovation',
#   'Swimming Pool Builders',
#   'Decking',
#   'Deck Repair',
#   'Deck Sanding',
#   'Deck Sealing',
#   'Deck Staining',
#   'Double Glazing',
#   'Draught Proofing',
#   'Glass Cutting',
#   'Glass Repair',
#   'Leaded Glass Repair',
#   'Triple Glazing',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel',
#   'Walk my doggo'],
#  'Business': ['Accounting',
#   'Admin',
#   'Alterations',
#   'Appliances',
#   'Architects',
#   'Assembly',
#   'Audio Visual',
#   'Auto Electrician',
#   'Bakers',
#   'Balloon Delivery',
#   'Barbers',
#   'Bathroom Renovation',
#   'Beauticians',
#   'Bicycle Service',
#   'Bricklayer',
#   'Building & Construction',
#   'Business',
#   'Cake Delivery',
#   'Car Air Conditioning Service',
#   'Car Aircon Regas',
#   'Car Body Work',
#   'Car Diagnostics',
#   'Car Detailing',
#   'Car Inspection',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Carburetor Tuning',
#   'Carpentry',
#   'Carpet Cleaning',
#   'Cat Care',
#   'Catering',
#   'Chef',
#   'Childcare & Safety',
#   'Cladding',
#   'Cleaning',
#   'Clearance Services',
#   'Clutch Replacement',
#   'Coaching',
#   'Coffee Delivery',
#   'Commercial Cleaning',
#   'Computers & IT',
#   'Concreting',
#   'Cooking',
#   'Counselling & Therapy',
#   'Courier Services',
#   'Crafting',
#   'Dance Lessons',
#   'Decking',
#   'Delivery',
#   'Design',
#   'Dessert Delivery',
#   'Dog Care',
#   'Draftsman',
#   'Driving',
#   'Electricians',
#   'Electronic Repair',
#   'End of lease cleaning',
#   'Engraving',
#   'Entertainment',
#   'Events',
#   'Fan Belt Replacement',
#   'Fencing',
#   'Fitness',
#   'Flooring',
#   'Florist',
#   'Flower Delivery',
#   'Food Delivery',
#   'Fresh Food Delivery',
#   'Furniture Assembly',
#   'Furniture Repair',
#   'Gardening',
#   'Gate Installation',
#   'Gift Delivery',
#   'Glaziers',
#   'Grocery Delivery',
#   'Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Head Unit Installation',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Help bartend my party',
#   'Help me move home',
#   'Help me with Excel',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Kitchen Installation',
#   'Kitchen Renovation',
#   'Landscaping',
#   'Laundry',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Light Bar Installation',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Mechanic',
#   'Models',
#   'Motorcycle Mechanic',
#   'Mow my backyard',
#   'Mow my lawn',
#   'Music Lessons',
#   'Oil & Filter Change',
#   'Painting',
#   'Palm Tree Removal',
#   'Paving',
#   'Pet Care',
#   'Photographers',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Real Estate',
#   'Removals',
#   'Roofing',
#   'Rubbish Removal',
#   'Seamstress',
#   'Sharpening',
#   'Staffing',
#   'Suspension Bushes Replacement',
#   'Surveyors',
#   'Swimming Lessons',
#   'Tailors',
#   'Takeaway & Delivery',
#   'Tattoo Artists',
#   'Tiling',
#   'Timing Belt Replacement',
#   'Tow Bar Installation',
#   'Tradesman',
#   'Translation',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'Tutoring',
#   'Vehicle Transport',
#   'Walk my doggo',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Winch Installation',
#   'Writing'],
#  'Car Body Work': ['Car Body Repair',
#   'Car Bumper Repair',
#   'Car Glass Repair',
#   'Car Paint Repair',
#   'Car Respray',
#   'Car Scratch Repair',
#   'Car Welding',
#   'Car Window Tinting',
#   'Car Wrapping',
#   'Paintless Dent Removal',
#   'Panel Beater',
#   'Vehicle Wraps',
#   'Windscreen Repair & Replacement',
#   'Brake Pad Replacement',
#   'Bull Bar Installation',
#   'Car Air Conditioning Service',
#   'Car Aircon Regas',
#   'Car Diagnostics',
#   'Car Window Replacement',
#   'Carburetor Tuning',
#   'Clutch Replacement',
#   'Fan Belt Replacement',
#   'Fuel Pump Replacement',
#   'Head Unit Installation',
#   'Light Bar Installation',
#   'Oil & Filter Change',
#   'Suspension Bushes Replacement',
#   'Timing Belt Replacement',
#   'Tow Bar Installation',
#   'Winch Installation',
#   'O2 Sensor Replacement'],
#  'Car Detailing': ['Car Detailing',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Car Inspection',
#   'Car Body Work',
#   'Mobile Mechanic',
#   'Wheel & Tyre Service',
#   'Car Cleaning',
#   'Car Engine Steam Cleaning',
#   'Car Interior Cleaning',
#   'Car Restoration',
#   'Car Roof Lining Repair',
#   'Car Valet',
#   'Leather Car Seat Restoration'],
#  'Car Repair': ['Alternator Repair',
#   'Brake Pad Replacement',
#   'Brake Repair',
#   'Bull Bar Installation',
#   'Car Air Conditioning Service',
#   'Car Aircon Regas',
#   'Car Aircon Repair',
#   'Car Diagnostics',
#   'Car Detailing',
#   'Car Seat Repair',
#   'Car Service',
#   'Car Upholstery Repair',
#   'Car Window Repair',
#   'Car Window Replacement',
#   'Carburetor Tuning',
#   'Clutch Replacement',
#   'CV Shaft Replacement',
#   'Engine Replacement',
#   'Exhaust Repair',
#   'Fan Belt Replacement',
#   'Fuel Injection Repair',
#   'Fuel Pump Replacement',
#   'Gearbox Repair',
#   'Head Gasket Repair',
#   'Head Unit Installation',
#   'Light Bar Installation',
#   'Mobile Mechanic',
#   'Oil & Filter Change',
#   'Radiator Repair',
#   'Steering Wheel Repair',
#   'Suspension Bushes Replacement',
#   'Suspension Repair',
#   'Timing Belt Replacement',
#   'Tow Bar Installation',
#   'Wiper Blade Replacement',
#   'Wiper Motor Repair',
#   'Wheel & Tyre Service',
#   'Winch Installation',
#   'O2 Sensor Replacement'],
#  'Car Service': ['Car Detailing',
#   'Car Repair',
#   'Alfa Romeo Service',
#   'Audi Service',
#   'BMW Service',
#   'Car Delivery Service',
#   'Fiat Service',
#   'Ford Service',
#   'Holden Service',
#   'Honda Service',
#   'Hyundai Service',
#   'Jaguar Service',
#   'Jeep Service',
#   'Kia Service',
#   'Land Rover Service',
#   'Lexus Service',
#   'Mazda Service',
#   'Mercedes-Benz Service',
#   'Mini Service',
#   'Nissan Service',
#   'Peugeot Service',
#   'Porsche Service',
#   'Renault Service',
#   'Saab Service',
#   'Seat Service',
#   'Subaru Service',
#   'Suzuki Service',
#   'Toyota Service',
#   'Volkswagen Service',
#   'Volvo Service',
#   'Brake Pad Replacement',
#   'Bull Bar Installation',
#   'Car Air Conditioning Service',
#   'Car Aircon Regas',
#   'Car Diagnostics',
#   'Car Window Replacement',
#   'Carburetor Tuning',
#   'Clutch Replacement',
#   'Fan Belt Replacement',
#   'Fuel Pump Replacement',
#   'Head Unit Installation',
#   'Light Bar Installation',
#   'Oil & Filter Change',
#   'Suspension Bushes Replacement',
#   'Timing Belt Replacement',
#   'Tow Bar Installation',
#   'Winch Installation',
#   'o2 Sensor Replacement'],
#  'Carpentry': ['Appliance Installation',
#   'Appliance Repair',
#   'Bathroom Cabinet Maker',
#   'Bosch Appliance Repair',
#   'Cabinet Design',
#   'Cabinet Installation',
#   'Cabinet Making',
#   'Coffee Machine Repairs',
#   'Cooker Hood Installation & Repair',
#   'Cooktop Installation',
#   'Custom Shelving',
#   'Custom TV Cabinets',
#   'Dishdrawer Installation',
#   'Dishwasher Not Draining',
#   'Dishwasher Repair',
#   'Dryer Installation',
#   'Fridge Repair & Installation',
#   'Freezer Installation',
#   'Furniture Makers',
#   'Gas Fitters',
#   'Gas Oven Repair and Installation',
#   'Gas Stove Installation & Repair',
#   'Ice Machine Repair & Installation',
#   'Kitchen Cabinet Maker',
#   'Microwave Repair',
#   'Oven Fan Repair',
#   'Oven Repair',
#   'Pikler Triangle Builder',
#   'Rangehood Installation',
#   'Rangehood Repairs',
#   'Refinishing',
#   'Samsung Fridge Repair',
#   'Staining',
#   'Stove Connection',
#   'Stove Installation',
#   'Timber Rot Repair',
#   'Vacuum Cleaner Repair',
#   'Washing Machine Levelling',
#   'Washing Machine Repairs & Installation',
#   'Wood Repair',
#   'Wood Rot Treatment'],
#  'Cat Care': ['Cat Boarding',
#   'Cat Care',
#   'Cat Grooming',
#   'Cat Sitting',
#   'Cat Training'],
#  'Catering': ['Bakers',
#   'BBQ Catering & Help',
#   'Banquet Catering',
#   'Buffet Catering',
#   'Chef',
#   'Coffee Catering',
#   'Catering',
#   'Dessert Catering',
#   'Party Catering',
#   'Wedding Caterer'],
#  'Chef': ['Catering',
#   'Cooking',
#   'Home Chef',
#   'Pastry Chef',
#   'Private Chef',
#   'Sushi Chef',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal'],
#  'Cladding': ['Bathroom Cladding',
#   'Ceiling Cladding',
#   'Cladding Repairs',
#   'Interior Wall Cladding',
#   'Shed Cladding',
#   'Shiplap Cladding',
#   'Stone Cladding'],
#  'Cleaning': ['Commercial Cleaning',
#   'House Cleaning',
#   'Laundry Services',
#   'Rubbish Removal',
#   'Window Cleaning',
#   'Car Cleaning',
#   'Car Engine Steam Cleaning',
#   'Car Interior Cleaning',
#   'Car Restoration',
#   'Car Roof Lining Repair',
#   'Car Valet',
#   'Leather Car Seat Restoration',
#   'Decluttering',
#   'Interior Designer',
#   'Kitchen Renovation',
#   'Kitchen Installation',
#   'Landscaping',
#   'Lawn Care',
#   'Laundry',
#   'Bulky Waste Collection',
#   'Commercial Waste Collection',
#   'Food Waste Disposal',
#   'Garden Waste Collection',
#   'Green Waste Collection',
#   'Household Waste Disposal',
#   'Kitchen Waste Disposal',
#   'Waste Bag Collection',
#   'Gardening',
#   'Painting',
#   'Removals',
#   'Repairs and Installations',
#   'Copywriting',
#   'Data Entry',
#   'Furniture Assembly',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel',
#   'Walk my doggo'],
#  'Computers & IT': ['Accounting',
#   'Admin',
#   'Alterations',
#   'Android App Development',
#   'App Development',
#   'Appliances',
#   'Apple Help',
#   'Apple Mac Repairs',
#   'Architects',
#   'Assembly',
#   'Audio Visual',
#   'Auto Electrician',
#   'Bakers',
#   'Balloon Delivery',
#   'Barbers',
#   'Bathroom Renovation',
#   'Beauticians',
#   'Bicycle Service',
#   'Bluetooth Help',
#   'Bricklayer',
#   'Building & Construction',
#   'Business',
#   'Cake Delivery',
#   'Car Body Work',
#   'Car Detailing',
#   'Car Inspection',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Carpentry',
#   'Carpet Cleaning',
#   'Cat Care',
#   'Catering',
#   'Chef',
#   'Childcare & Safety',
#   'Cladding',
#   'Cleaning',
#   'Clearance Services',
#   'Coaching',
#   'Coffee Delivery',
#   'Commercial Cleaning',
#   'Computer Backup Help',
#   'Computer Hardware',
#   'Computer Repairs',
#   'Computer Support',
#   'Computer Training',
#   'Computer Upgrades',
#   'Computers & IT',
#   'Concreting',
#   'Cooking',
#   'Counselling & Therapy',
#   'Courier Services',
#   'Data Recovery',
#   'Decking',
#   'Delivery',
#   'Design',
#   'Dessert Delivery',
#   'Dog Care',
#   'Draftsman',
#   'Driving',
#   'Electricians',
#   'Electronic Repair',
#   'Email Setup',
#   'Engraving',
#   'Entertainment',
#   'Events',
#   'Fencing',
#   'File Conversion Help',
#   'Firewall Setup',
#   'Fitness',
#   'Flooring',
#   'Florist',
#   'Flower Delivery',
#   'Food Delivery',
#   'Fresh Food Delivery',
#   'Furniture Assembly',
#   'Furniture Repair',
#   'Gardening',
#   'Gate Installation',
#   'Gift Delivery',
#   'Glaziers',
#   'Google Chrome Help',
#   'Grocery Delivery',
#   'Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Help me move home',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Network Setup',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Internet Help',
#   'iPhone Help',
#   'iPhone Repair',
#   'iPhone Screen Replacement',
#   'iPod Repair',
#   'iMovie Help',
#   'iOS Development',
#   'iPod Repair',
#   'iTunes Help',
#   'IT Support',
#   'Keynote Help',
#   'Kitchen Renovation',
#   'Laptop Data Recovery',
#   'Laptop Repair',
#   'Landscaping',
#   'Laundry',
#   'Lawncare',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Linux Help',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Mac OS Help',
#   'Mac Setup',
#   'Macbook Air Repair',
#   'Macbook Repairs',
#   'Malware Removal',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Mechanic',
#   'Microsoft Access Help',
#   'Microsoft Excel Help',
#   'Microsoft Help',
#   'Microsoft Office Help',
#   'Microsoft Onedrive Help',
#   'Microsoft Onenote Help',
#   'Microsoft Outlook Help',
#   'Microsoft Powerpoint Help',
#   'Microsoft Publisher Help',
#   'Microsoft Windows Help',
#   'Microsoft Word Help',
#   'Mobile App Development',
#   'Models',
#   'Motorcycle Mechanic',
#   'Mow my backyard',
#   'Mow my lawn',
#   'Music Lessons',
#   'Network Troubleshooting',
#   'Operating System Installation',
#   'Organise Computer Folders',
#   'Painting',
#   'Paving',
#   'Pet Care',
#   'Photographers',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Printer Help',
#   'Pest Control',
#   'Real Estate',
#   'Removals',
#   'Router Modem Setup',
#   'Roofing',
#   'Rubbish Removal',
#   'Scanner Setup',
#   'Screen Repair',
#   'Seamstress',
#   'Server Upgrading & Support',
#   'Sharpening',
#   'Skype Help',
#   'Software Development',
#   'Software Help',
#   'Speed Up Computer',
#   'Staffing',
#   'Surveyors',
#   'Swimming Lessons',
#   'Takeaway & Delivery',
#   'Tailors',
#   'Tattoo Artists',
#   'Technical Support',
#   'Tiling',
#   'Troubleshooting',
#   'Tradesman',
#   'Translation',
#   'Tree Surgeons',
#   'Tutoring',
#   'Vehicle Transport',
#   'Virus Removal',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Walk my doggo',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Windows & Doors',
#   'Windows Help',
#   'Windows Installation',
#   'Wifi Extender Setup',
#   'Wifi Help',
#   'Writing'],
#  'Concreting': ['Concrete Cutting',
#   'Concrete Delivery',
#   'Concrete Repair',
#   'Concrete Resurfacing'],
#  'Decking': ['Appliance Installation',
#   'Appliance Repair',
#   'Bosch Appliance Repair',
#   'Coffee Machine Repairs',
#   'Cooker Hood Installation & Repair',
#   'Cooktop Installation',
#   'Dishdrawer Installation',
#   'Dishwasher Not Draining',
#   'Dishwasher Repair',
#   'Dryer Installation',
#   'Freezer Installation',
#   'Fridge Repair & Installation',
#   'Gas Fitters',
#   'Gas Oven Repair and Installation',
#   'Gas Stove Installation & Repair',
#   'Ice Machine Repair & Installation',
#   'Microwave Repair',
#   'Oven Fan Repair',
#   'Oven Repair',
#   'Rangehood Installation',
#   'Rangehood Repairs',
#   'Samsung Fridge Repair',
#   'Stove Connection',
#   'Stove Installation',
#   'Vacuum Cleaner Repair',
#   'Washing Machine Levelling',
#   'Washing Machine Repairs & Installation',
#   'Deck Repair',
#   'Deck Sanding',
#   'Deck Sealing',
#   'Deck Staining'],
#  'Delivery': ['Balloon Delivery',
#   'Cake Delivery',
#   'Car Detailing',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Car Delivery Service',
#   'Coffee Delivery',
#   'Courier Services',
#   'Delivery',
#   'Dessert Delivery',
#   'Fresh Food Delivery',
#   'Food Delivery',
#   'Gift Delivery',
#   'Grocery Delivery',
#   'Aldi Grocery Delivery',
#   'Coles Grocery Delivery',
#   'Costco Grocery Delivery',
#   'Woolworths Delivery',
#   'Local Mobile Mechanic',
#   'Mobile Mechanic',
#   'Takeaway & Delivery',
#   'Vehicle Transport',
#   'Wheel & Tyre Service',
#   'Apple Store Delivery',
#   'BBQ Delivery',
#   'Bunnings Delivery',
#   'Christmas Tree Delivery',
#   'Concrete Delivery',
#   'Fantastic Furniture Delivery',
#   'Freedom Furniture Delivery',
#   'Furniture Delivery',
#   'IGA Delivery',
#   'IKEA Delivery',
#   'Kmart Delivery',
#   'Super Amart Delivery',
#   'TV Delivery',
#   'Umart Delivery',
#   'Ute Removals',
#   'Wardrobe Delivery',
#   'eBay Delivery',
#   'Boat Transport',
#   'Caravan Transport',
#   'Motorcycle Transport',
#   'Deliver something for me'],
#  'Design': ['3D Modelling',
#   '3D Rendering',
#   'Adobe After Effects Designer',
#   'Adobe Illustrator Designer',
#   'Adobe InDesign Designer',
#   'Adobe Photoshop Designer',
#   'Animation',
#   'Architectural Rendering & Visualisation',
#   'Arborist',
#   'Branding Designer',
#   'Brochure Design',
#   'Building Designers',
#   'Business Card Design',
#   'Desktop Publishing',
#   'Digital Design',
#   'Drawing',
#   'End of lease cleaning',
#   'Floor Planning',
#   'Flyer Design',
#   'Garage Conversion',
#   'Graphic Designers',
#   'Help bartend my party',
#   'Help me move home',
#   'Help me with Excel',
#   'House Extensions',
#   'House Renovation',
#   'Illustrators',
#   'Interior Architects',
#   'Invitation Design',
#   'Landing Page Design',
#   'Logo Design',
#   'Loft Conversion',
#   'Mow my backyard',
#   'Mow my lawn',
#   'Packaging Design',
#   'Palm Tree Removal',
#   'Poster Design',
#   'Print Design',
#   'Sign Writing',
#   'SketchUp Help',
#   'T-Shirt Printing',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'Typography Design',
#   'UI Design',
#   'UX Design',
#   'Walk my doggo',
#   'Washing machine repair'],
#  'Dog Care': ['Dog Boarding',
#   'Dog Day Care',
#   'Dog Food Delivery',
#   'Dog Grooming',
#   'Dog Running',
#   'Dog Sitting',
#   'Dog Training',
#   'Dog Walking',
#   'Dog Wash',
#   'Mobile Dog Grooming',
#   'Mobile Dog Wash',
#   'Puppy Training',
#   'Walk my doggo',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel'],
#  'Draftsman': ['Drafting',
#   'Architectural Rendering & Visualisation',
#   'Building Designers',
#   'Floor Planning',
#   'Garage Conversion',
#   'House Extensions',
#   'House Renovation',
#   'Interior Architects',
#   'Loft Conversion',
#   'AutoCAD Designer',
#   'CAD Designer',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal'],
#  'Driving': ['Car Inspection',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Car Detailing',
#   'Car Body Work',
#   'Car Body Repair',
#   'Car Bumper Repair',
#   'Car Glass Repair',
#   'Car Paint Repair',
#   'Car Respray',
#   'Car Scratch Repair',
#   'Car Welding',
#   'Car Window Tinting',
#   'Car Wrapping',
#   'Paintless Dent Removal',
#   'Panel Beater',
#   'Vehicle Wraps',
#   'Windscreen Repair & Replacement',
#   'Airport Pick-ups',
#   'Delivery Drop-offs',
#   'Chauffeur Services',
#   'Mechanic',
#   'Brake Pad Replacement',
#   'Bull Bar Installation',
#   'Car Air Conditioning Service',
#   'Car Aircon Regas',
#   'Car Diagnostics',
#   'Car Window Replacement',
#   'Carburetor Tuning',
#   'Clutch Replacement',
#   'Fan Belt Replacement',
#   'Fuel Pump Replacement',
#   'Head Unit Installation',
#   'Light Bar Installation',
#   'Oil & Filter Change',
#   'Suspension Bushes Replacement',
#   'Timing Belt Replacement',
#   'Tow Bar Installation',
#   'Winch Installation',
#   'o2 Sensor Replacement',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel',
#   'Walk my doggo'],
#  'Electricians': ['ADSL Technician',
#   'Air Source Heat Pump Installation & Repairs',
#   'Aircon Cleaning',
#   'Aircon Installation',
#   'Aircon Repair',
#   'Appliance Installation',
#   'Appliance Repair',
#   'Bar Fridge Repairs',
#   'Bosch Appliance Repair',
#   'Coffee Machine Repairs',
#   'Cooker Hood Installation & Repair',
#   'Cooktop Installation',
#   'Data Cable Installation',
#   'Dishdrawer Installation',
#   'Dishwasher Not Draining',
#   'Dishwasher Repair',
#   'Downlights Installation',
#   'Dryer Installation',
#   'Electric Shower Installation',
#   'Electrical Inspection and Testing',
#   'Electrical Installation',
#   'Electrical Rewiring',
#   'Freezer Installation',
#   'Fridge Repair & Installation',
#   'Gas Fitters',
#   'Gas Oven Repair and Installation',
#   'Gas Stove Installation & Repair',
#   'Generator Repair',
#   'Ice Machine Repair & Installation',
#   'Lamp Repairs',
#   'LG Air Conditioning Service',
#   'Light Installation',
#   'Light Repair',
#   'Microwave Repair',
#   'NBN Electrician',
#   'Oven Fan Repair',
#   'Oven Repair',
#   'Power Point Installation',
#   'Rangehood Installation',
#   'Rangehood Repairs',
#   'Samsung Fridge Repair',
#   'Smoke Alarm Installation',
#   'Sockets and Switches Installation',
#   'Solar Panel Installation',
#   'Stove Connection',
#   'Stove Installation',
#   'Telephone Engineers',
#   'Vacuum Cleaner Repair',
#   'Water Heater Repairs and Installation',
#   'Washing Machine Levelling',
#   'Washing Machine Repairs & Installation'],
#  'Entertainment': ['Audio Visual',
#   'Bagpiper',
#   'Balloon Artist',
#   'Band Hire',
#   'Belly Dancer',
#   'Clown',
#   'Comedians',
#   'Costume Character Entertainer',
#   'DJ',
#   'Dancer',
#   'End of lease cleaning',
#   'Face Painting',
#   'Fix my washing machine',
#   'Help bartend my party',
#   'Help me move home',
#   'Help me with Excel',
#   'Halloween Face Painter',
#   'Jugglers',
#   'Magician',
#   'Mime Artist',
#   'Mow my backyard',
#   'Mow my lawn',
#   'Singer',
#   'Walk my doggo'],
#  'Events': ['Budgeting Help',
#   'Financial Advisor',
#   'Financial Modelling',
#   'Financial Planning',
#   'Financial Reporting',
#   'MYOB Training',
#   'Mortgage Advisor',
#   'Pension Advisor',
#   'Tax Advisor',
#   'XERO Training',
#   'Balloon Decorators',
#   'Birthday Decorators',
#   'Birthday Grams',
#   'Christmas Decorating',
#   'Event Decorator',
#   'Event Security',
#   'Event Setup & Cleaning',
#   'Event Staff',
#   'Flower Wall',
#   'Motivational Speaker',
#   'Party Helpers',
#   'Wedding Car Hire',
#   'Work Christmas Party',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel',
#   'Walk my doggo'],
#  'Fencing': ['Aluminium Fencing',
#   'Balustrading',
#   'Bamboo Fencing',
#   'Brick Fencing',
#   'Brushwood Fencing',
#   'Chain Link Fencing',
#   'Fence Installation',
#   'Fence Repair',
#   'Fence Staining',
#   'Fencing',
#   'Glass Fencing',
#   'Iron Fencing',
#   'PVC Fencing',
#   'Picket Fencing',
#   'Temporary Fencing',
#   'Wood Fencing'],
#  'Fitness': ['Aerobics Classes',
#   'At Home Personal Training',
#   'Basketball Training',
#   'Bikram Yoga',
#   'Bootcamp Training',
#   'Boxing Instructor',
#   'Cycling Training',
#   'Female Personal Training',
#   'Fitness Equipment Installation',
#   'Group Fitness Training',
#   'Gym Buddy',
#   'HIIT Training',
#   'Help me move home',
#   'Help me with Excel',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Mow my lawn',
#   'Personal Training',
#   'Pilates Instructor',
#   'Pregnancy Fitness',
#   'Sports Coaches',
#   'Table Tennis Coaching',
#   'Triathlon Training',
#   'Walk my doggo',
#   'Weight Loss Training',
#   'Yoga Instructor',
#   'Zumba Classes'],
#  'Flooring': ['Appliance Installation',
#   'Appliance Repair',
#   'Bamboo Flooring',
#   'Bathroom Flooring',
#   'Bosch Appliance Repair',
#   'Carpet Laying & Installation',
#   'Coffee Machine Repairs',
#   'Concrete Floor Polishing',
#   'Concrete Flooring',
#   'Cooker Hood Installation & Repair',
#   'Cooktop Installation',
#   'Cork Flooring',
#   'Dishdrawer Installation',
#   'Dishwasher Not Draining',
#   'Dishwasher Repair',
#   'Dryer Installation',
#   'Epoxy Floor Coating',
#   'Floating Flooring',
#   'Floor Repair',
#   'Floor Sanding',
#   'Floorboards',
#   'Freezer Installation',
#   'Fridge Repair & Installation',
#   'Gas Fitters',
#   'Gas Oven Repair and Installation',
#   'Gas Stove Installation & Repair',
#   'Hardwood Flooring',
#   'Heated Floor Installation',
#   'Ice Machine Repair & Installation',
#   'Laminate Flooring',
#   'Limestone Flooring',
#   'Linoleum Flooring',
#   'Marble Flooring',
#   'Microwave Repair',
#   'Natural Stone Flooring',
#   'Oven Fan Repair',
#   'Oven Repair',
#   'Rangehood Installation',
#   'Rangehood Repairs',
#   'Samsung Fridge Repair',
#   'Skirting Boards',
#   'Stone Flooring',
#   'Stove Connection',
#   'Stove Installation',
#   'Terrazzo Flooring',
#   'Timber Flooring',
#   'Vacuum Cleaner Repair',
#   'Vinyl Flooring',
#   'Washing Machine Levelling',
#   'Washing Machine Repairs & Installation'],
#  'Florist': ['Flower Delivery',
#   'Fresh Food Delivery',
#   'Food Delivery',
#   'Flower Arrangements',
#   'Wedding Florist',
#   'Valentines Flower Delivery'],
#  'Furniture Assembly': ['BBQ Assembly',
#   'Basketball Hoop System Assembly',
#   'Bunnings Assembly',
#   'Cube Storage Assembly',
#   'Disassembly',
#   'Exercise Bike Assembly',
#   'Fantastic Furniture Assembly',
#   'Furniture Disassembly',
#   'Harvey Norman Furniture Assembly',
#   'Home Gym Assembly',
#   'IKEA Assembly',
#   'Inversion Table Assembly',
#   'Kids Bike Assembly',
#   'Nordictrack Assembly',
#   'Office Furniture Assembly',
#   'Outdoor Furniture Assembly',
#   'PC Assembly',
#   'Playground Assembly',
#   'Pool Table Assembly',
#   'Shelf Assembly',
#   'Sofa Assembly',
#   'Spring Free Trampoline Assembly',
#   'Swing Set Assembly',
#   'Table Assembly',
#   'Table Tennis Table Assembly',
#   'Toy Assembly',
#   'Trampoline Assembly',
#   'Treadmill Assembly',
#   'Vuly Trampoline Assembly',
#   'Wardrobe Assembly'],
#  'Furniture Repair': ['Chair Repair',
#   'Recliner Chair Repair',
#   'Upholstery Repair',
#   'Attic Ladder Installation',
#   'Awning Repair',
#   'BBQ Repair',
#   'Bed Repairs',
#   'Bistro Blind Installation',
#   'Blind Repairs',
#   'Blueboard Installation',
#   'Bunnings Shed Installation',
#   'Cafe Blinds Installation',
#   'Cat Door Installation',
#   'Ceiling Fan Installation',
#   'Ceiling Fan Repair',
#   'Cement Sheeting Installation',
#   'Chainsaw Service & Repair',
#   'Chandelier Installation',
#   'Chicken Coops',
#   'Chicken Runs',
#   'Clock Repair',
#   'Clothesline Installation',
#   'Coffee Table Repair',
#   'Conservatory Repairs',
#   'Cornice Repair',
#   'Cot Repair',
#   'Curtain Rod Installation',
#   'Curtains & Blinds Fitter',
#   'Custom Mailboxes',
#   'Dining Chair Repair',
#   'Dog House Builder',
#   'Door Frame Installation',
#   'Door Installation',
#   'Door Knob Installation',
#   'Drone Recovery',
#   'Fireplace Installation',
#   'Fitness Equipment Installation',
#   'Flyscreen Installation',
#   'Garden Shed Installation & Repair',
#   'General Labour',
#   'Gyprock Installation',
#   'Hills Hoist Removal',
#   'Home Gym Repair',
#   'Hot Tub Repair',
#   'IKEA Benchtop Installation',
#   'Internal Door Installation',
#   'Jack of all Trades',
#   'Kaboodle Kitchen Installation',
#   'Kitchen Cupboard Repair',
#   'Kitchen Drawer Repair',
#   'Kitchen Sink Installation',
#   'Lattice Installation',
#   'Laundry Tub Installation',
#   'Letterbox Replacement',
#   'Lounge Repair',
#   'MDF Cutting',
#   'MDF Installation',
#   'Mirror Cutting',
#   'Mirror Repair',
#   'Office Chair Repair',
#   'Outdoor Blinds Installation',
#   'Patio Sliding Door Repair',
#   'Pet Door Installation',
#   'Pool Table Refelting',
#   'Pressure Washer Repair',
#   'Privacy Screens',
#   'Property Maintenance',
#   'Recliner Repair',
#   'Render Repair',
#   'Ring Doorbell Installation',
#   'Roller Shutter Blinds Repair & Installation',
#   'Roman Blinds Installation',
#   'Screen Door Hinge Repairs',
#   'Sewing Machine Repair',
#   'Shower Screen Installation',
#   'Sign Hanging',
#   'Signage Installers',
#   'Sink Installation',
#   'Sliding Door Repair',
#   'Sofa Bed Repairs',
#   'Soundproofing',
#   'Table Lamp Repair',
#   'Table Tennis Table Repair',
#   'Tent Repair',
#   'Toilet Seat Fitting',
#   'Tool Repair',
#   'Trampoline Repair Service',
#   'Treadmill Repair',
#   'Vanity Mirror Installation',
#   'Venetian Blind Repair',
#   'Villaboard Installation',
#   'Water Tank Installation & Repair',
#   'Weather Stripping',
#   'Weatherboard Repair',
#   'Window Frame Repair',
#   'Window Repair',
#   'Wooden Blind Fitter',
#   'Furniture Repair'],
#  'Gardening': ['Landscaping',
#   'Lawn Care',
#   'Backhoeing',
#   'Brushcutting',
#   'Garden Centre Delivery',
#   'Garden Clearance',
#   'Garden Designers',
#   'Garden Edging',
#   'Garden Machinery Servicing',
#   'Garden Planting',
#   'Garden Pond Maintenance',
#   'Garden Seat Installation',
#   'Garden Tidy Up',
#   'Garden Tool Repair',
#   'Garden Tool Sharpening',
#   'Hedge Planting',
#   'Mulching',
#   'Plant Delivery',
#   'Planter Boxes',
#   'Rotary Hoeing',
#   'Shrub & Bush Trimming',
#   'Yard Work',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'Gardening'],
#  'Gate Installation': ['Gate Installation',
#   'Metal Gate Repair',
#   'Pool Gate Repairs',
#   'Sliding Gate Repair',
#   'Attic Ladder Installation',
#   'Awning Repair',
#   'BBQ Repair',
#   'Bed Repairs',
#   'Bistro Blind Installation',
#   'Blind Repairs',
#   'Blueboard Installation',
#   'Bunnings Shed Installation',
#   'Cafe Blinds Installation',
#   'Cat Door Installation',
#   'Ceiling Fan Installation',
#   'Ceiling Fan Repair',
#   'Cement Sheeting Installation',
#   'Chainsaw Service & Repair',
#   'Chandelier Installation',
#   'Chicken Coops',
#   'Chicken Runs',
#   'Clock Repair',
#   'Clothesline Installation',
#   'Coffee Table Repair',
#   'Conservatory Repairs',
#   'Cornice Repair',
#   'Cot Repair',
#   'Curtain Rod Installation',
#   'Curtains & Blinds Fitter',
#   'Custom Mailboxes',
#   'Dining Chair Repair',
#   'Dog House Builder',
#   'Door Frame Installation',
#   'Door Installation',
#   'Door Knob Installation',
#   'Drone Recovery',
#   'Fireplace Installation',
#   'Fitness Equipment Installation',
#   'Flyscreen Installation',
#   'Garden Shed Installation & Repair',
#   'General Labour',
#   'Gyprock Installation',
#   'Hills Hoist Removal',
#   'Home Gym Repair',
#   'Hot Tub Repair',
#   'IKEA Benchtop Installation',
#   'Internal Door Installation',
#   'Jack of all Trades',
#   'Kaboodle Kitchen Installation',
#   'Kitchen Cupboard Repair',
#   'Kitchen Drawer Repair',
#   'Kitchen Sink Installation',
#   'Lattice Installation',
#   'Laundry Tub Installation',
#   'Letterbox Replacement',
#   'Lounge Repair',
#   'MDF Cutting',
#   'MDF Installation',
#   'Mirror Cutting',
#   'Mirror Repair',
#   'Office Chair Repair',
#   'Outdoor Blinds Installation',
#   'Patio Sliding Door Repair',
#   'Pet Door Installation',
#   'Pool Table Refelting',
#   'Pressure Washer Repair',
#   'Privacy Screens',
#   'Property Maintenance',
#   'Recliner Repair',
#   'Render Repair',
#   'Ring Doorbell Installation',
#   'Roller Shutter Blinds Repair & Installation',
#   'Roman Blinds Installation',
#   'Screen Door Hinge Repairs',
#   'Sewing Machine Repair',
#   'Shower Screen Installation',
#   'Sign Hanging',
#   'Signage Installers',
#   'Sink Installation',
#   'Sliding Door Repair',
#   'Sofa Bed Repairs',
#   'Soundproofing',
#   'Table Lamp Repair',
#   'Table Tennis Table Repair',
#   'Tent Repair',
#   'Toilet Seat Fitting',
#   'Tool Repair',
#   'Trampoline Repair Service',
#   'Treadmill Repair',
#   'Vanity Mirror Installation',
#   'Venetian Blind Repair',
#   'Villaboard Installation',
#   'Water Tank Installation & Repair',
#   'Weather Stripping',
#   'Weatherboard Repair',
#   'Window Frame Repair',
#   'Window Repair',
#   'Wooden Blind Fitter',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal'],
#  'Gift Delivery': ['Aldi Grocery Delivery',
#   'Baby Gift Delivery',
#   'Birthday Balloon Delivery',
#   'Birthday Gift Delivery',
#   'Christmas Gift Delivery',
#   'Coles Grocery Delivery',
#   'Costco Grocery Delivery',
#   "Father's Day Gift Delivery",
#   'Flower & Balloon Delivery',
#   'Gift Basket Delivery',
#   'Gift Wrapping',
#   'Inflated Helium Balloon Delivery',
#   "Mother's Day Gift Delivery",
#   'Personalised Balloon Delivery',
#   'Personalised Gift Delivery',
#   "Valentine's Gift Delivery",
#   'Woolworths Delivery'],
#  'Glaziers': ['Glaziers',
#   'Double Glazing',
#   'Draught Proofing',
#   'Glass Cutting',
#   'Glass Repair',
#   'Leaded Glass Repair',
#   'Triple Glazing'],
#  'Glass Services': ['Car Glass Repair',
#   'Double Glazing',
#   'Draught Proofing',
#   'Glass Cutting',
#   'Glass Repair',
#   'Leaded Glass Repair',
#   'Triple Glazing',
#   'Windscreen Repair & Replacement'],
#  'Grocery Delivery': ['Fresh Food Delivery',
#   'Gift Delivery',
#   'Apple Store Delivery',
#   'BBQ Delivery',
#   'Bunnings Delivery',
#   'Christmas Tree Delivery',
#   'Concrete Delivery',
#   'Fantastic Furniture Delivery',
#   'Freedom Furniture Delivery',
#   'Furniture Delivery',
#   'IGA Delivery',
#   'IKEA Delivery',
#   'Kmart Delivery',
#   'Super Amart Delivery',
#   'TV Delivery',
#   'Umart Delivery',
#   'Ute Removals',
#   'Wardrobe Delivery',
#   'eBay Delivery',
#   'Aldi Grocery Delivery',
#   'Coles Grocery Delivery',
#   'Costco Grocery Delivery',
#   'Woolworths Delivery'],
#  'Hair Removal': ['Hair Removal',
#   'Facial Hair Removal',
#   "Ladies' Bikini Waxing",
#   'Mobile Waxing',
#   'Waxing'],
#  'Hairdressers': ['Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Kitchen Renovation',
#   'Landscaping',
#   'Laundry',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Mechanic',
#   'Models',
#   'Motorcycle Mechanic',
#   'Music Lessons',
#   'Painting',
#   'Paving',
#   'Pest Control',
#   'Pet Care',
#   'Photographers',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Real Estate',
#   'Removals',
#   'Roofing',
#   'Rubbish Removal',
#   'Seamstress',
#   'Sharpening',
#   'Staffing',
#   'Surveyors',
#   'Swimming Lessons',
#   'Tailors',
#   'Takeaway & Delivery',
#   'Tattoo Artists',
#   'Tiling',
#   'Tradesman',
#   'Translation',
#   'Tree Surgeons',
#   'Tutoring',
#   'Vehicle Transport',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Writing',
#   'Blow Dry',
#   'Curly Hair Specialists',
#   'Hair Braiding',
#   'Haircut and Trimming',
#   'Kids Haircut',
#   'Mobile Hairdressers'],
#  'Handyman': ['Accounting',
#   'Admin',
#   'Alterations',
#   'Appliances',
#   'Architects',
#   'Assembly',
#   'Audio Visual',
#   'Auto Electrician',
#   'Bakers',
#   'Balloon Delivery',
#   'Barbers',
#   'Bathroom Renovation',
#   'Beauticians',
#   'Bicycle Service',
#   'Bricklayer',
#   'Building & Construction',
#   'Business',
#   'Cake Delivery',
#   'Car Body Work',
#   'Car Detailing',
#   'Car Inspection',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Carpentry',
#   'Carpet Cleaning',
#   'Cat Care',
#   'Catering',
#   'Chef',
#   'Childcare & Safety',
#   'Cladding',
#   'Cleaning',
#   'Clearance Services',
#   'Coaching',
#   'Coffee Delivery',
#   'Commercial Cleaning',
#   'Computers & IT',
#   'Concreting',
#   'Cooking',
#   'Counselling & Therapy',
#   'Courier Services',
#   'Dance Lessons',
#   'Decking',
#   'Deck Repair',
#   'Deck Sanding',
#   'Deck Sealing',
#   'Deck Staining',
#   'Delivery',
#   'Design',
#   'Dessert Delivery',
#   'Dog Care',
#   'Draftsman',
#   'Driving',
#   'Electricians',
#   'Electronic Repair',
#   'Engraving',
#   'Entertainment',
#   'Events',
#   'Fencing',
#   'Fitness',
#   'Flooring',
#   'Florist',
#   'Flower Delivery',
#   'Food Delivery',
#   'Fresh Food Delivery',
#   'Furniture Assembly',
#   'Furniture Repair',
#   'Gardening',
#   'Gate Installation',
#   'Gift Delivery',
#   'Glaziers',
#   'Grocery Delivery',
#   'Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Kitchen Renovation',
#   'Landscaping',
#   'Laundry',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Mechanic',
#   'Models',
#   'Motorcycle Mechanic',
#   'Music Lessons',
#   'Painting',
#   'Paving',
#   'Pest Control',
#   'Pet Care',
#   'Photographers',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Real Estate',
#   'Removals',
#   'Roofing',
#   'Rubbish Removal',
#   'Seamstress',
#   'Sharpening',
#   'Staffing',
#   'Surveyors',
#   'Swimming Lessons',
#   'Tailors',
#   'Takeaway & Delivery',
#   'Tattoo Artists',
#   'Tiling',
#   'Tradesman',
#   'Translation',
#   'Tree Surgeons',
#   'Tutoring',
#   'Vehicle Transport',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Writing',
#   'Attic Ladder Installation',
#   'Awning Repair',
#   'BBQ Repair',
#   'Bed Repairs',
#   'Bistro Blind Installation',
#   'Blind Repairs',
#   'Blueboard Installation',
#   'Bunnings Shed Installation',
#   'Cafe Blinds Installation',
#   'Cat Door Installation',
#   'Ceiling Fan Installation',
#   'Ceiling Fan Repair',
#   'Cement Sheeting Installation',
#   'Chainsaw Service & Repair',
#   'Chandelier Installation',
#   'Chicken Coops',
#   'Chicken Runs',
#   'Clock Repair',
#   'Clothesline Installation',
#   'Coffee Table Repair',
#   'Conservatory Repairs',
#   'Cornice Repair',
#   'Cot Repair',
#   'Curtain Rod Installation',
#   'Curtains & Blinds Fitter',
#   'Custom Mailboxes',
#   'Dining Chair Repair',
#   'Dog House Builder',
#   'Door Frame Installation',
#   'Door Installation',
#   'Door Knob Installation',
#   'Drone Recovery',
#   'Fireplace Installation',
#   'Fitness Equipment Installation',
#   'Flyscreen Installation',
#   'Garden Shed Installation & Repair',
#   'General Labour',
#   'Gyprock Installation',
#   'Hills Hoist Removal',
#   'Home Gym Repair',
#   'Hot Tub Repair',
#   'IKEA Benchtop Installation',
#   'Internal Door Installation',
#   'Jack of all Trades',
#   'Kaboodle Kitchen Installation',
#   'Kitchen Cupboard Repair',
#   'Kitchen Drawer Repair',
#   'Kitchen Sink Installation',
#   'Lattice Installation',
#   'Laundry Tub Installation',
#   'Letterbox Replacement',
#   'Lounge Repair',
#   'MDF Cutting',
#   'MDF Installation',
#   'Mirror Cutting',
#   'Mirror Repair',
#   'Office Chair Repair',
#   'Outdoor Blinds Installation',
#   'Patio Sliding Door Repair',
#   'Pet Door Installation',
#   'Pool Table Refelting',
#   'Pressure Washer Repair',
#   'Privacy Screens',
#   'Property Maintenance',
#   'Recliner Repair',
#   'Render Repair',
#   'Ring Doorbell Installation',
#   'Roller Shutter Blinds Repair & Installation',
#   'Roman Blinds Installation',
#   'Screen Door Hinge Repairs',
#   'Sewing Machine Repair',
#   'Shower Screen Installation',
#   'Sign Hanging',
#   'Signage Installers',
#   'Sink Installation',
#   'Sliding Door Repair',
#   'Sofa Bed Repairs',
#   'Soundproofing',
#   'Table Lamp Repair',
#   'Table Tennis Table Repair',
#   'Tent Repair',
#   'Toilet Seat Fitting',
# ...
#   'Lessons',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'End of lease cleaning'],
#  'Interior Designer': ['Interior Design',
#   'Architectural Rendering & Visualisation',
#   'Building Designers',
#   'Floor Planning',
#   'Garage Conversion',
#   'House Extensions',
#   'House Renovation',
#   'Interior Architects',
#   'Loft Conversion',
#   'Bathroom Designers',
#   'Coffee Shop Designers',
#   'Home Bar Designers',
#   'Home Stagers',
#   'Interior Lighting Designers',
#   'Kitchen Designers',
#   'Office Interior Designers',
#   'Restaurant Designers',
#   'Space Planners'],
#  'Kitchen Renovation': ['Kitchen Renovation', 'Kitchen Installation'],
#  'Kitchen Installation': ['Kaboodle Kitchen Installation',
#   'Kitchen Cupboard Repair',
#   'Kitchen Drawer Repair',
#   'Kitchen Sink Installation'],
#  'Landscaping': ['Arborist',
#   'Boring Excavation',
#   'Chainsawing',
#   'Commercial Landscaping',
#   'Drip Irrigation Systems',
#   'Earthmoving Contractors',
#   'End of lease cleaning',
#   'Fix my washing machine',
#   'Garden Benches',
#   'Gardening',
#   'Hard Landscaping',
#   'Hedging',
#   'Help bartend my party',
#   'Help me move home',
#   'Help me with Excel',
#   'Irrigation Repair',
#   'Land Clearing',
#   'Lawn Care',
#   'Landscape Contractors',
#   'Landscape Designers',
#   'Landscape Lighting',
#   'Levelling',
#   'Mow my backyard',
#   'Mow my lawn',
#   'Palm Tree Removal',
#   'Retaining Walls',
#   'Snow Plowing & Removal',
#   'Soil & Sand Delivery',
#   'Sprinkler System Installation',
#   'Trench Digging',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'Walk my doggo',
#   'Water Features',
#   'Wood Chipping & Mulching'],
#  'Laundry': ['Laundry Services',
#   'Commercial Laundry',
#   'Curtain Dry Cleaning',
#   'Ironing',
#   'Same-Day Dry Cleaning',
#   'Wedding Dress Dry Cleaning',
#   'Fix my washing machine'],
#  'Lawn Care': ['Lawn Mowing',
#   'Lawn Aeration',
#   'Lawn Fertilization',
#   'Lawn Weeding',
#   'Lawn Edging',
#   'Lawn Dethatching',
#   'Lawn Overseeding',
#   'Lawn Pest Control',
#   'Lawn Disease Treatment',
#   'Lawn Irrigation',
#   'Lawn Drainage',
#   'Lawn Soil Testing',
#   'Lawn Mower Blade Sharpening',
#   'Lawn Mower Repair',
#   'Lawn Fertilisation',
#   'Lawn Repair',
#   'Lawn Seeding',
#   'Lawn Treatment',
#   'Leaf Raking',
#   'Turf Laying',
#   'Turf Repair',
#   'Whipper Snippering',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'Mow my backyard',
#   'Mow my lawn'],
#  'Legal Services': ['Legal Services'],
#  'Lessons': ['Accounting',
#   'Accounting Tutor',
#   'Admin',
#   'Acting Lessons',
#   'Algebra Tutor',
#   'Alterations',
#   'Appliances',
#   'Archery Lessons',
#   'Architects',
#   'Assembly',
#   'Audio Visual',
#   'Auto Electrician',
#   'Bakers',
#   'Balloon Delivery',
#   'Barbers',
#   'Bathroom Renovation',
#   'Beauticians',
#   'Bicycle Service',
#   'Bricklayer',
#   'Building & Construction',
#   'Business',
#   'Cake Delivery',
#   'Car Body Work',
#   'Car Detailing',
#   'Car Inspection',
#   'Car Repair',
#   'Car Service',
#   'Car Wash',
#   'Carpentry',
#   'Carpet Cleaning',
#   'Cat Care',
#   'Catering',
#   'Chef',
#   'Childcare & Safety',
#   'Chess Lessons',
#   'Cladding',
#   'Cleaning',
#   'Clearance Services',
#   'Coaching',
#   'Coffee Delivery',
#   'Commercial Cleaning',
#   'Computers & IT',
#   'Concreting',
#   'Cooking',
#   'Counselling & Therapy',
#   'Courier Services',
#   'Dance Lessons',
#   'Decking',
#   'Delivery',
#   'Design',
#   'Dessert Delivery',
#   'Dog Care',
#   'Draftsman',
#   'Drawing Lessons',
#   'Driving',
#   'Driving Lessons',
#   'Drone Training',
#   'Drone Training',
#   'Electricians',
#   'Electronic Repair',
#   'Engraving',
#   'Entertainment',
#   'Events',
#   'Fencing',
#   'Fitness',
#   'Flooring',
#   'Florist',
#   'Flower Delivery',
#   'Food Delivery',
#   'Fresh Food Delivery',
#   'Furniture Assembly',
#   'Furniture Repair',
#   'Gardening',
#   'Gate Installation',
#   'Gift Delivery',
#   'Glaziers',
#   'Grocery Delivery',
#   'Hair Removal',
#   'Hairdressers',
#   'Handyman',
#   'Health & Wellness',
#   'Heating & Cooling',
#   'Home & Lifestyle',
#   'Home Automation and Security',
#   'Home Theatre',
#   'House Cleaning',
#   'Interior Designer',
#   'Karate Lessons',
#   'Kitesurfing Lessons',
#   'Kitchen Renovation',
#   'Landscaping',
#   'Laundry',
#   'Lawn Care',
#   'Legal Services',
#   'Lessons',
#   'Local Mobile Mechanic',
#   'Locksmith',
#   'Makeup Artist',
#   'Marketing',
#   'Martial Arts',
#   'Maths Tutor',
#   'Mechanic',
#   'Models',
#   'Motorcycle Lessons',
#   'Motorcycle Mechanic',
#   'Music Lessons',
#   'Painting',
#   'Painting Lessons',
#   'Paving',
#   'Pet Care',
#   'Photographers',
#   'Physics Tutor',
#   'Plasterer',
#   'Plumbing',
#   'Pool Maintenance',
#   'Portuguese Tutor',
#   'Public Speaking',
#   'Pest Control',
#   'Python Tutor',
#   'Real Estate',
#   'Removals',
#   'Roofing',
#   'Rubbish Removal',
#   'Science Tutor',
#   'Sailing Lessons',
#   'Sewing Lessons',
#   'Sharpening',
#   'Skateboard Lessons',
#   'Ski Lessons',
#   'Skateboard Lessons',
#   'Spanish Lessons',
#   'Staffing',
#   'Surveyors',
#   'Surf Lessons',
#   'Swimming Lessons',
#   'Tailors',
#   'Takeaway & Delivery',
#   'Tattoo Artists',
#   'Tennis Lessons',
#   'Tiling',
#   'Tradesman',
#   'Translation',
#   'Tree Surgeons',
#   'Tutoring',
#   'University Tutor',
#   'Vehicle Transport',
#   'Wall Hanging and Mounting',
#   'Wallpapering',
#   'Waste Collection & Disposal',
#   'Waterproofing',
#   'Web',
#   'Wedding',
#   'Wheel & Tyre Service',
#   'Window Cleaning',
#   'Windows & Doors',
#   'Writing'],
#  'Local Mobile Mechanic': ['Car Body Repair',
#   'Car Bumper Repair',
#   'Car Detailing',
#   'Car Glass Repair',
#   'Car Inspection',
#   'Car Paint Repair',
#   'Car Repair',
#   'Car Respray',
#   'Car Scratch Repair',
#   'Car Service',
#   'Car Wash',
#   'Car Welding',
#   'Car Window Tinting',
#   'Car Window Replacement',
#   'Car Wrapping',
#   'Mechanic',
#   'Mobile Alloy Wheel Repair',
#   'Mobile Auto Electrician',
#   'Mobile Bike Repair',
#   'Mobile Car Airconditioning Service',
#   'Mobile Car Battery Replacement',
#   'Mobile Car Dent Repair',
#   'Mobile Car Diagnostics',
#   'Mobile Car Valet',
#   'Mobile Car Wrapping',
#   'Mobile Motorcycle Mechanic',
#   'Mobile Scratch Repair',
#   'Mobile Tyre Fitting',
#   'Mobile Tyre Repair',
#   'Mobile Wheel Refurbishment',
#   'Motorcycle Mechanic',
#   'Oil & Filter Change',
#   'Paintless Dent Removal',
#   'Panel Beater',
#   'Suspension Bushes Replacement',
#   'Timing Belt Replacement',
#   'Tow Bar Installation',
#   'Vehicle Wraps',
#   'Wheel & Tyre Service',
#   'Winch Installation',
#   'Windscreen Repair & Replacement'],
#  'Locksmith': ['Car Key Repair',
#   'Car Key Replacement',
#   'Emergency Locksmith',
#   'Key Cutting',
#   'Lock Installation',
#   'Lock Replacement',
#   'Locksmith',
#   'Mobile Locksmith'],
#  'Makeup Artist': ['Eyebrow Microblading',
#   'Eyebrow Threading',
#   'Eyebrow Waxing',
#   'Eyelash Extensions',
#   'Eyelash Lift and Tint',
#   'Eyelash Perming',
#   'Manicure',
#   'Nail Technicians',
#   'Pedicure',
#   'Spray Tanning',
#   'Hair Stylist',
#   'Makeup Tutor'],
#  'Marketing': ['Budgeting Help',
#   'Financial Advisor',
#   'Financial Modelling',
#   'Financial Planning',
#   'Financial Reporting',
#   'MYOB Training',
#   'Mortgage Advisor',
#   'Pension Advisor',
#   'Tax Advisor',
#   'XERO Training',
#   'Advertising',
#   'Analytics',
#   'Content Marketing',
#   'Data Analysis',
#   'Digital Marketing',
#   'Digital Media',
#   'Email Marketing',
#   'Facebook Marketing',
#   'Focus Group Candidates',
#   'Google Adwords Management',
#   'Google Analytics',
#   'Instagram Marketing',
#   'Mailchimp',
#   'Market Research',
#   'Marketing Strategy',
#   'Mystery Shopping',
#   'Online Marketing',
#   'PR',
#   'SEO',
#   'Sales Assistant',
#   'Salesforce Help',
#   'Search Engine Marketing',
#   'Social Media Marketing & Management',
#   'Twitter Marketing',
#   'User Testing'],
#  'Martial Arts': ['Jiu Jitsu Classes',
#   'Judo Classes',
#   'Kickboxing Training',
#   'MMA Training',
#   'Self Defence Classes',
#   'Taekwondo Classes'],
#  'Mechanic': ['Mobile Mechanic',
#   'Motorcycle Mechanic',
#   'Car Body Repair',
#   'Car Bumper Repair',
#   'Car Glass Repair',
#   'Car Paint Repair',
#   'Car Respray',
#   'Car Scratch Repair',
#   'Car Welding',
#   'Car Window Tinting',
#   'Car Wrapping',
#   'Paintless Dent Removal',
#   'Panel Beater',
#   'Vehicle Wraps',
#   'Windscreen Repair & Replacement',
#   'Car Detailing',
#   'Car Cleaning',
#   'Car Engine Steam Cleaning',
#   'Car Interior Cleaning',
#   'Car Restoration',
#   'Car Roof Lining Repair',
#   'Car Valet',
#   'Leather Car Seat Restoration',
#   'Car Inspection',
#   'Blue Slips',
#   'Pink Slips',
#   'Pre Purchase Car Inspection',
#   'Car Repair',
#   'Alternator Repair',
#   'Brake Repair',
#   'CV Shaft Replacement',
#   'Car Aircon Repair',
#   'Car Seat Repair',
#   'Car Upholstery Repair',
#   'Car Window Repair',
#   'Engine Replacement',
#   'Exhaust Repair',
#   'Fuel Injection Repair',
#   'Gearbox Repair',
#   'Head Gasket Repair',
#   'Radiator Repair',
#   'Steering Wheel Repair',
#   'Suspension Repair',
#   'Water Pump Repair',
#   'Wiper Blade Replacement',
#   'Wiper Motor Repair',
#   'Car Service',
#   'Alfa Romeo Service',
#   'Audi Service',
#   'BMW Service',
#   'Car Delivery Service',
#   'Fiat Service',
#   'Ford Service',
#   'Holden Service',
#   'Honda Service',
#   'Hyundai Service',
#   'Jaguar Service',
#   'Jeep Service',
#   'Kia Service',
#   'Land Rover Service',
#   'Lexus Service',
#   'Mazda Service',
#   'Mercedes-Benz Service',
#   'Mini Service',
#   'Nissan Service',
#   'Peugeot Service',
#   'Porsche Service',
#   'Renault Service',
#   'Saab Service',
#   'Seat Service',
#   'Subaru Service',
#   'Suzuki Service',
#   'Toyota Service',
#   'Volkswagen Service',
#   'Volvo Service',
#   'Car Wash',
#   'Attic Ladder Installation',
#   'Awning Repair',
#   'BBQ Repair',
#   'Bed Repairs',
#   'Bistro Blind Installation',
#   'Blind Repairs',
#   'Blueboard Installation',
#   'Bunnings Shed Installation',
#   'Cafe Blinds Installation',
#   'Cat Door Installation',
#   'Ceiling Fan Installation',
#   'Ceiling Fan Repair',
#   'Cement Sheeting Installation',
#   'Chainsaw Service & Repair',
#   'Chandelier Installation',
#   'Chicken Coops',
#   'Chicken Runs',
#   'Clock Repair',
#   'Clothesline Installation',
#   'Coffee Table Repair',
#   'Conservatory Repairs',
#   'Cornice Repair',
#   'Cot Repair',
#   'Curtain Rod Installation',
#   'Curtains & Blinds Fitter',
#   'Custom Mailboxes',
#   'Dining Chair Repair',
#   'Dog House Builder',
#   'Door Frame Installation',
#   'Door Installation',
#   'Door Knob Installation',
#   'Drone Recovery',
#   'Fireplace Installation',
#   'Fitness Equipment Installation',
#   'Flyscreen Installation',
#   'Garden Shed Installation & Repair',
#   'General Labour',
#   'Gyprock Installation',
#   'Hills Hoist Removal',
#   'Home Gym Repair',
#   'Hot Tub Repair',
#   'IKEA Benchtop Installation',
#   'Internal Door Installation',
#   'Jack of all Trades',
#   'Kaboodle Kitchen Installation',
#   'Kitchen Cupboard Repair',
#   'Kitchen Drawer Repair',
#   'Kitchen Sink Installation',
#   'Lattice Installation',
#   'Laundry Tub Installation',
#   'Letterbox Replacement',
#   'Lounge Repair',
#   'MDF Cutting',
#   'MDF Installation',
#   'Mirror Cutting',
#   'Mirror Repair',
#   'Office Chair Repair',
#   'Outdoor Blinds Installation',
#   'Patio Sliding Door Repair',
#   'Pet Door Installation',
#   'Pool Table Refelting',
#   'Pressure Washer Repair',
#   'Privacy Screens',
#   'Property Maintenance',
#   'Recliner Repair',
#   'Render Repair',
#   'Ring Doorbell Installation',
#   'Roller Shutter Blinds Repair & Installation',
#   'Roman Blinds Installation',
#   'Screen Door Hinge Repairs',
#   'Sewing Machine Repair',
#   'Shower Screen Installation',
#   'Sign Hanging',
#   'Signage Installers',
#   'Sink Installation',
#   'Sliding Door Repair',
#   'Sofa Bed Repairs',
#   'Soundproofing',
#   'Table Lamp Repair',
#   'Table Tennis Table Repair',
#   'Tent Repair',
#   'Toilet Seat Fitting',
#   'Tool Repair',
#   'Trampoline Repair Service',
#   'Treadmill Repair',
#   'Vanity Mirror Installation',
#   'Venetian Blind Repair',
#   'Villaboard Installation',
#   'Water Tank Installation & Repair',
#   'Weather Stripping',
#   'Weatherboard Repair',
#   'Window Frame Repair',
#   'Window Repair',
#   'Wooden Blind Fitter',
#   'Brake Pad Replacement',
#   'Bull Bar Installation',
#   'Car Air Conditioning Service',
#   'Car Aircon Regas',
#   'Car Diagnostics',
#   'Car Window Replacement',
#   'Carburetor Tuning',
#   'Clutch Replacement',
#   'Fan Belt Replacement',
#   'Fuel Pump Replacement',
#   'Head Unit Installation',
#   'Light Bar Installation',
#   'Oil & Filter Change',
#   'Suspension Bushes Replacement',
#   'Timing Belt Replacement',
#   'Tow Bar Installation',
#   'Winch Installation',
#   'O2 Sensor Replacement',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal'],
#  'Models': ['Models',
#   'Car Body Repair',
#   'Car Bumper Repair',
#   'Car Glass Repair',
#   'Car Paint Repair',
#   'Car Respray',
#   'Car Scratch Repair',
#   'Car Welding',
#   'Car Window Tinting',
#   'Car Wrapping',
#   'Paintless Dent Removal',
#   'Panel Beater',
#   'Vehicle Wraps',
#   'Windscreen Repair & Replacement',
#   'Moped Repair',
#   'Motorcycle Seat Repair',
#   'Motorcycle Tyre Repair',
#   'Quad Bike Repair',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal',
#   'Help me move home',
#   'Fix my washing machine',
#   'Mow my backyard',
#   'Help bartend my party',
#   'End of lease cleaning',
#   'Mow my lawn',
#   'Deliver something for me',
#   'Help me with Excel',
#   'Walk my doggo'],
#  'Motorcycle Mechanic': ['Mobile Mechanic',
#   'Mobile Motorcycle Mechanic',
#   'Moped Repair',
#   'Motorcycle Seat Repair',
#   'Motorcycle Tyre Repair',
#   'Quad Bike Repair'],
#  'Moped Repair': ['Moped Repair',
#   'Motorcycle Seat Repair',
#   'Motorcycle Tyre Repair',
#   'Quad Bike Repair'],
#  'Music Lessons': ['Banjo Lessons',
#   'Bass Guitar Lessons',
#   'Cello Lessons',
#   'Clarinet Lessons',
#   'Dance Lessons',
#   'Drum Lessons',
#   'Electric Guitar Lessons',
#   'Flute Lessons',
#   'Guitar Lessons',
#   'Harmonica Lessons',
#   'Keyboard Lessons',
#   'Mandolin Lessons',
#   'Martial Arts',
#   'Piano Lessons',
#   'Saxophone Lessons',
#   'Singing Lessons',
#   'Swimming Lessons',
#   'Tutoring',
#   'Ukulele Lessons',
#   'Violin Lessons'],
#  'Painting': ['Interior Painting',
#   'Exterior Painting',
#   'Fence Painting',
#   'Wall Painting',
#   'Fence Staining',
#   'Deck Painting',
#   'Fence Repair',
#   'Deck Staining',
#   'Wallpaper Removal',
#   'Wallpaper Installation',
#   'Wallpaper Repair',
#   'Wallpaper Stripping',
#   'Wallpaper Hanging',
#   'Wallpaper Staining',
#   'Wallpaper Painting',
#   'Wallpaper Sealing',
#   'Wallpaper Sanding',
#   'Wallpaper Priming',
#   'Wallpaper Finishing',
#   'Wallpaper Cutting',
#   'Wallpaper Measuring',
#   'Wallpaper Matching',
#   'Wallpaper Design',
#   'Wallpaper Pattern Matching',
#   'Wallpaper Texture',
#   'Wallpaper Color Matching',
#   'Wallpaper Border Installation',
#   'Wallpaper Border Repair',
#   'Wallpaper Border Staining',
#   'Wallpaper Border Painting',
#   'Wallpaper Border Sealing',
#   'Wallpaper Border Sanding',
#   'Wallpaper Border Priming',
#   'Wallpaper Border Finishing',
#   'Wallpaper Border Cutting',
#   'Wallpaper Border Measuring',
#   'Wallpaper Border Matching',
#   'Wallpaper Border Design',
#   'Wallpaper Border Pattern Matching',
#   'Wallpaper Border Texture',
#   'Wallpaper Border Color Matching',
#   'Painting Lessons',
#   'Apartment Painting',
#   'Basement Painting',
#   'Commercial Painting',
#   'Dining Room Painting',
#   'Furniture Painting',
#   'Graffiti Artist',
#   'House Painters',
#   'Kitchen Cabinet Painting',
#   'Office Decorator',
#   'Paint Stripping'],
#  'Paving': ['Concreting',
#   'Decking',
#   'Fencing',
#   'Flooring',
#   'Landscaping',
#   'Pest Control',
#   'Pool Maintenance',
#   'Roofing',
#   'Waterproofing',
#   'Brick Paving',
#   'Paving Repairs'],
#  'Pest Control': ['Pest Control',
#   'Possum Removal',
#   'Wasp Nest Removal',
#   'Arborist',
#   'Palm Tree Removal',
#   'Tree Felling',
#   'Tree Lopper',
#   'Tree Pruning',
#   'Tree Removal'],
#  'Pet Care': ['Aquarium Maintenance',
#   'Bird Sitting',
#   'Cat Care',
#   'Dog Care',
#   'Fish Tank Repair',
#   'Mobile Pet Services',
#   'Pet Feeding',
#   'Pet Food Delivery',
#   'Pet Grooming',
#   'Pet Minding',
#   'Pet Sitting',
#   'Pet Taxi',
#   'Pet Transport',
#   'Rabbit Boarding',
#   'Reptile Boarding',
#   'Small Animal Boarding']}
